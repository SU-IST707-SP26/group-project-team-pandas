# %%
# %pip install pandas

# %%
# uploading data 
import pandas as pd

# NYC Open Data CSV download link
url = "https://data.cityofnewyork.us/api/views/43nn-pn8j/rows.csv?accessType=DOWNLOAD"

print("Loading data... This may take a minute.")

# Read directly from the web
df = pd.read_csv(url)

print("Data loaded successfully.")
print("Shape:", df.shape)

# Preview
df.head()
# Out:
# Loading data... This may take a minute.
# Data loaded successfully.
# Shape: (296270, 27)
#       CAMIS                  DBA           BORO BUILDING  \
# 0  50160505     STARBUCKS # 1955      Manhattan        0
# 1  50180152         Malta Coffee      Manhattan      250
# 2  50180331  NONG GENG JI 37 LLC         Queens   135-15
# 3  50165900    AFTER 5 WINGS INC  Staten Island       39
# 4  50179318  KOSHER BAY 2025 LLC       Brooklyn        2
#
#                       STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 0  JFK INTERNATIONAL AIRPORT      NaN  2299392549                 NaN
# 1           EAST   90 STREET  10128.0  9294089562                 NaN
# 2                  37 AVENUE  11354.0  6469441519                 NaN
# 3          VICTORY BOULEVARD  10301.0  7187994608                 NaN
# 4             NEPTUNE AVENUE  11235.0  3475548811                 NaN
#
#   INSPECTION DATE ACTION  ... INSPECTION TYPE   Latitude  Longitude  \
# ...

# %% [markdown]
# ## Missing Values Analysis

# %%
# Display statistical summary
print("Statistical Summary:")
df.describe()

# %% [markdown]
# ## Statistical Summary

# %%
# Display data types and info
print("\nData Types and Info:")
df.info()

# %%
# Display first few rows
print("First few rows:")
df.head()

# %% [markdown]
# ## Dataset Overview
#
# Get a quick overview of the dataset structure and first few rows.

# %%
# Load the dataset
# Update the file path based on your data file format (csv, xlsx, etc.)
df = pd.read_csv('../data/healthcare/your_dataset.csv')

print("Dataset loaded successfully!")
print(f"Shape: {df.shape}")

# %% [markdown]
# ## Data Loading
#
# Load the healthcare dataset from the data directory.

# %%
# Import Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Healthcare Dataset Initial Exploration
#
# This notebook performs initial exploratory data analysis (EDA) on the healthcare dataset to understand its structure, contents, and basic statistics.
