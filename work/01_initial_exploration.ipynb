# %% [markdown]
# ## Uploading Data
# This notebook performs initial exploratory data analysis (EDA) on the restaurant inspection dataset to understand its structure, contents, and basic statistics.

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.0.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# uploading data 
import pandas as pd

# NYC Open Data CSV download link
url = "https://data.cityofnewyork.us/api/views/43nn-pn8j/rows.csv?accessType=DOWNLOAD"

# Read directly from the web
df = pd.read_csv(url)

print("Shape:", df.shape)

# Preview
df.head()
# Out:
# Shape: (296504, 27)
# /tmp/ipykernel_3414/703061283.py:8: DtypeWarning: Columns (0: PHONE) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)
#       CAMIS                                           DBA       BORO BUILDING  \
# 0  50161894                                         PATOK  Manhattan        1
# 1  50142157  THE ATRIUM AT LA GUARDIA - THE LITTLE FLOWER     Queens        1
# 2  50179717                       THE BROOKLYN STRATEGIST   Brooklyn      148
# 3  50179742                                    LA VENTANA     Queens    54-20
# 4  50174691                             MISTER EVERYTHING     Queens    34-39
#
#               STREET  ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0      HERALD SQUARE  10001.0  9173276332                 NaN      01/01/1900
# 1   Central Terminal      NaN  9723556751                 NaN      01/01/1900
# 2  PIERREPONT STREET  11201.0  7185763035                 NaN      01/01/1900
# 3           BROADWAY  11377.0  6462464060                 NaN      01/01/1900
# 4          31 STREET  11106.0  3478379294                 NaN      01/01/1900
#
#   ACTION  ... INSPECTION TYPE   Latitude  Longitude  Community Board  \
# 0    NaN  ...             NaN  40.750542 -73.987541            105.0
# 1    NaN  ...             NaN   0.000000   0.000000              NaN
# 2    NaN  ...             NaN  40.694744 -73.991414            302.0
# 3    NaN  ...             NaN  40.753021 -73.906377            402.0
# 4    NaN  ...             NaN  40.759009 -73.927767            401.0
#
#   Council District Census Tract        BIN           BBL   NTA  \
# 0              4.0      10900.0  1089436.0  1.008100e+09  MN17
# 1              NaN          NaN        NaN  4.000000e+00   NaN
# 2             33.0        900.0  3424482.0  3.002440e+09  BK09
# 3             26.0      25500.0  4545010.0  4.011930e+09  QN63
# 4             22.0       5700.0  4008152.0  4.006080e+09  QN70
#
#                                    Location
# 0  POINT (-73.987541021756 40.750541907818)
# 1                                       NaN
# 2   POINT (-73.99141370071 40.694743896486)
# 3  POINT (-73.906377296437 40.753021336026)
# 4  POINT (-73.927766958994 40.759009392964)
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Missing Values Analysis

# %%
# Display statistical summary
print("Statistical Summary:")
df.describe()
# Out:
# Statistical Summary:
#               CAMIS        ZIPCODE          SCORE       Latitude  \
# count  2.965040e+05  293380.000000  280099.000000  294914.000000
# mean   4.804663e+07   10706.677285      25.158523      40.298222
# std    3.764916e+06     616.063672      18.754134       4.163517
# min    3.007544e+07    6605.000000       0.000000       0.000000
# 25%    5.000370e+07   10023.000000      12.000000      40.686670
# 50%    5.009139e+07   11101.000000      21.000000      40.732868
# 75%    5.012945e+07   11232.000000      33.000000      40.761240
# max    5.018173e+07   69361.000000     203.000000      40.912822
#
#            Longitude  Community Board  Council District   Census Tract  \
# count  294914.000000    291800.000000     291827.000000  291827.000000
# mean      -73.159571       254.861960         20.549308   29887.958612
# std         7.558059       130.414681         15.666349   31325.314400
# min       -74.249101       101.000000          1.000000     100.000000
# 25%       -73.988654       106.000000          4.000000    8000.000000
# 50%       -73.955736       302.000000         20.000000   17300.000000
# 75%       -73.893772       402.000000         34.000000   42600.000000
# max         0.000000       595.000000         51.000000  162100.000000
#
#                 BIN           BBL
# count  2.905620e+05  2.949140e+05
# mean   2.584943e+06  2.478094e+09
# std    1.356299e+06  1.338454e+09
# min    1.000000e+06  1.000000e+00
# 25%    1.050747e+06  1.011030e+09
# 50%    3.021602e+06  3.007940e+09
# 75%    4.011497e+06  4.006320e+09
# max    5.799501e+06  5.270001e+09

# %% [markdown]
# ## Statistical Summary

# %%
print(f"Shape: {df.shape}")
# Out:
# Shape: (296504, 27)

# %%
# Display data types and info
print("\nData Types and Info:")
df.info()
# Out:
# Data Types and Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 296504 entries, 0 to 296503
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   CAMIS                  296504 non-null  int64
#  1   DBA                    296502 non-null  str
#  2   BORO                   296504 non-null  str
#  3   BUILDING               295588 non-null  str
#  4   STREET                 296503 non-null  str
#  5   ZIPCODE                293380 non-null  float64
#  6   PHONE                  296492 non-null  object
#  7   CUISINE DESCRIPTION    293326 non-null  str
#  8   INSPECTION DATE        296504 non-null  str
#  9   ACTION                 293326 non-null  str
#  10  VIOLATION CODE         291031 non-null  str
#  11  VIOLATION DESCRIPTION  291030 non-null  str
#  12  CRITICAL FLAG          296504 non-null  str
#  13  SCORE                  280099 non-null  float64
#  14  GRADE                  146251 non-null  str
#  15  GRADE DATE             136843 non-null  str
#  16  RECORD DATE            296504 non-null  str
#  17  INSPECTION TYPE        293326 non-null  str
#  18  Latitude               294914 non-null  float64
#  19  Longitude              294914 non-null  float64
#  20  Community Board        291800 non-null  float64
#  21  Council District       291827 non-null  float64
#  22  Census Tract           291827 non-null  float64
#  23  BIN                    290562 non-null  float64
#  24  BBL                    294914 non-null  float64
#  25  NTA                    291800 non-null  str
#  26  Location               291800 non-null  str
# dtypes: float64(9), int64(1), object(1), str(16)
# memory usage: 61.1+ MB

# %%
#See how many null values are in each column --zeek
print(df.isnull().sum())
# Out:
# CAMIS                         0
# DBA                           2
# BORO                          0
# BUILDING                    916
# STREET                        1
# ZIPCODE                    3124
# PHONE                        12
# CUISINE DESCRIPTION        3178
# INSPECTION DATE               0
# ACTION                     3178
# VIOLATION CODE             5473
# VIOLATION DESCRIPTION      5474
# CRITICAL FLAG                 0
# SCORE                     16405
# GRADE                    150253
# GRADE DATE               159661
# RECORD DATE                   0
# INSPECTION TYPE            3178
# Latitude                   1590
# Longitude                  1590
# Community Board            4704
# Council District           4677
# Census Tract               4677
# BIN                        5942
# BBL                        1590
# NTA                        4704
# Location                   4704
# dtype: int64

# %%
#get rid of nulls
def clean_restaurant_inspection_data(df):
    # Make a copy to avoid modifying original
    df_clean = df.copy()
    
    # Basic info cleaning
    df_clean['DBA'] = df_clean['DBA'].fillna("Unknown Business")
    df_clean['BUILDING'] = df_clean['BUILDING'].fillna("No Number")
    df_clean['STREET'] = df_clean['STREET'].fillna("Unknown Street")
    df_clean['PHONE'] = df_clean['PHONE'].fillna("No Phone Listed")
    
    # Zipcode by borough
    df_clean['ZIPCODE'] = df_clean.groupby('BORO')['ZIPCODE'].transform(lambda x: x.fillna(x.median()))
    
    # Inspection related
    df_clean['CUISINE DESCRIPTION'] = df_clean['CUISINE DESCRIPTION'].fillna("Unspecified")
    df_clean['ACTION'] = df_clean['ACTION'].fillna("No Action Recorded")
    df_clean['INSPECTION TYPE'] = df_clean['INSPECTION TYPE'].fillna("Unspecified")
    df_clean['VIOLATION CODE'] = df_clean['VIOLATION CODE'].fillna("No Violation")
    df_clean['VIOLATION DESCRIPTION'] = df_clean['VIOLATION DESCRIPTION'].fillna("No Violation Found")
    
    # Grades and scores
    df_clean['SCORE'] = df_clean['SCORE'].fillna(-1)
    df_clean['GRADE'] = df_clean['GRADE'].fillna("Not Graded")
    df_clean['GRADE DATE'] = df_clean['GRADE DATE'].fillna(df_clean['INSPECTION DATE'])
    
    # Location data
    for coord in ['Latitude', 'Longitude']:
        df_clean[coord] = df_clean.groupby('BORO')[coord].transform(lambda x: x.fillna(x.median()))
    
    # Administrative boundaries - FIX HERE
    admin_cols = ['Community Board', 'Council District', 'Census Tract', 'NTA']
    for col in admin_cols:
        df_clean[col] = df_clean.groupby('BORO')[col].transform(lambda x: 
            x.fillna(x.mode().iloc[0] if not x.mode().empty else -1))
    
    # Building numbers
    df_clean['BIN'] = df_clean['BIN'].fillna(0)
    df_clean['BBL'] = df_clean['BBL'].fillna(0)
    
    # Location string
    df_clean['Location'] = df_clean['Location'].fillna('Unknown Location')
    
    return df_clean

# %%
# Import Required Libraries
# !pip install matplotlib
# !pip install seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
# Out:
# Requirement already satisfied: matplotlib in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Requirement already satisfied: seaborn in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (2.4.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (3.0.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# Convert INSPECTION DATE to datetime
df["INSPECTION DATE"] = pd.to_datetime(df["INSPECTION DATE"], errors="coerce")

# Filter data between 2015 and 2025
df_2015_2025 = df[
    (df["INSPECTION DATE"].dt.year >= 2015) &
    (df["INSPECTION DATE"].dt.year <= 2025)
].copy()

# %%
print("Original:", df.shape)
print("2015–2025:", df_2015_2025.shape)

print(
    df_2015_2025["INSPECTION DATE"].min(),
    "to",
    df_2015_2025["INSPECTION DATE"].max()
)
# Out:
# Original: (296504, 27)
# 2015–2025: (282659, 27)
# 2015-02-11 00:00:00 to 2025-12-31 00:00:00

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.countplot(data=df_2015_2025, x="GRADE", order=["A","B","C"])

plt.title("Distribution of Inspection Grades (2015–2025)")
plt.xlabel("Grade")
plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=df_2015_2025,
    x="BORO",
    hue="GRADE",
    order=df_2015_2025["BORO"].value_counts().index
)

plt.title("Inspection Grades by Borough")
plt.xlabel("Borough")
plt.ylabel("Count")
plt.legend(title="Grade")

plt.show()

# %%
df_2015_2025["YearMonth"] = df_2015_2025["INSPECTION DATE"].dt.to_period("M")

monthly = df_2015_2025.groupby("YearMonth")["CAMIS"].count()

plt.figure(figsize=(12,5))
monthly.plot()

plt.title("Inspection Volume Over Time (2015–2025)")
plt.xlabel("Year")
plt.ylabel("Number of Inspections")

plt.show()

# %%
plt.figure(figsize=(6,4))

sns.boxplot(
    data=df_2015_2025,
    x="GRADE",
    y="SCORE",
    order=["A","B","C"]
)

plt.title("Inspection Scores by Grade")
plt.xlabel("Grade")
plt.ylabel("Score")

plt.show()

# %%
#Histogram of Grade
plt.hist(df_2015_2025.SCORE)
# Out:
# (array([1.31066e+05, 9.44940e+04, 3.03450e+04, 9.75700e+03, 2.90000e+03,
#         9.90000e+02, 4.59000e+02, 6.10000e+01, 5.20000e+01, 1.00000e+01]),
#  array([  0. ,  20.3,  40.6,  60.9,  81.2, 101.5, 121.8, 142.1, 162.4,
#         182.7, 203. ]),
#  <BarContainer object of 10 artists>)

# %%
df.BORO.unique()
df_Manhatten = df[df['BORO'] == 'Manhattan'].copy()
df_Manhatten.describe()
# Out:
#               CAMIS        ZIPCODE             INSPECTION DATE          SCORE  \
# count  1.097580e+05  108181.000000                      109758  102891.000000
# mean   4.792242e+07   10022.589928  2022-09-01 03:02:25.039086      24.340778
# min    3.019184e+07   10000.000000         1900-01-01 00:00:00       0.000000
# 25%    5.000111e+07   10010.000000         2023-05-04 00:00:00      12.000000
# 50%    5.008926e+07   10017.000000         2024-06-21 00:00:00      20.000000
# 75%    5.012823e+07   10027.000000         2025-04-25 00:00:00      32.000000
# max    5.018172e+07   11371.000000         2026-02-11 00:00:00     203.000000
# std    3.853899e+06      31.062012                         NaN      18.589785
#
#             Latitude      Longitude  Community Board  Council District  \
# count  109280.000000  109280.000000    107703.000000     107703.000000
# mean       40.165990     -72.913832       105.081372          3.652322
# min         0.000000     -74.019624       101.000000          1.000000
# 25%        40.727889     -73.995191       103.000000          2.000000
# 50%        40.749847     -73.985468       105.000000          3.000000
# 75%        40.765952     -73.970937       107.000000          4.000000
# max        40.872885       0.000000       164.000000         10.000000
# std         4.860411       8.822974         3.042519          2.368541
#
#         Census Tract           BIN           BBL
# count  107703.000000  1.072480e+05  1.092800e+05
# mean    10078.823617  1.037265e+06  9.909380e+08
# min       201.000000  1.000000e+06  1.000000e+00
# 25%      4700.000000  1.010941e+06  1.004820e+09
# 50%      9200.000000  1.028604e+06  1.008590e+09
# 75%     13400.000000  1.061828e+06  1.012990e+09
# max     31704.000000  1.799161e+06  1.270000e+09
# std      6740.815560  3.620622e+04  1.367207e+08

# %%
#Grading in Manhatten


plt.figure(figsize=(6,4))

sns.boxplot(
    data=df_Manhatten,
    x="GRADE",
    y="SCORE",
    order=["A","B","C"]
)

plt.title("Inspection Scores by Grade (In Manhatten)")
plt.xlabel("Grade")
plt.ylabel("Score")

plt.show()
#Showing the boxplot throughout the years
