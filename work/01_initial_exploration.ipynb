# %% [markdown]
# ## Uploading Data
# This notebook performs initial exploratory data analysis (EDA) on the restaurant inspection dataset to understand its structure, contents, and basic statistics.

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# uploading data 
import pandas as pd

# NYC Open Data CSV download link
url = "https://data.cityofnewyork.us/api/views/43nn-pn8j/rows.csv?accessType=DOWNLOAD"

# Read directly from the web
df = pd.read_csv(url)

print("Shape:", df.shape)

# Preview
df.head()
# Out:
# Shape: (297291, 27)
#       CAMIS                         DBA       BORO BUILDING  \
# 0  50000390                      DUNKIN     Queens      NaN
# 1  50166957                        OLMO   Brooklyn      103
# 2  50098126  HUMAN RESOURCES (BERGAMOS)  Manhattan       26
# 3  50111558              PIER SIDE CAFE  Manhattan        1
# 4  50176246        ARAMARK SERVICES INC  Manhattan      388
#
#                       STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 0  JFK INTERNATIONAL AIRPORT  11430.0  7187514796          Coffee/Tea
# 1            SARATOGA AVENUE  11233.0  7185411430                 NaN
# 2          VANDERBILT AVENUE  10017.0  9294364067                 NaN
# 3                INTREPID SQ      NaN  9172843261                 NaN
# 4           GREENWICH STREET  10013.0  7327785266                 NaN
#
#   INSPECTION DATE                                           ACTION  ...  \
# 0      06/02/2022  Violations were cited in the following area(s).  ...
# 1      01/01/1900                                              NaN  ...
# 2      01/01/1900                                              NaN  ...
# 3      01/01/1900                                              NaN  ...
# 4      01/01/1900                                              NaN  ...
#
#                                      INSPECTION TYPE   Latitude  Longitude  \
# 0  Administrative Miscellaneous / Initial Inspection        NaN        NaN
# 1                                                NaN  40.683186 -73.917235
# 2                                                NaN  40.753277 -73.977756
# 3                                                NaN   0.000000   0.000000
# 4                                                NaN  40.720652 -74.010098
#
#    Community Board Council District Census Tract        BIN           BBL  \
# 0              NaN              NaN          NaN        NaN           NaN
# 1            316.0             41.0      37300.0  3337910.0  3.015060e+09
# 2            105.0              4.0       9400.0  1035360.0  1.012780e+09
# 3              NaN              NaN          NaN        NaN  1.000000e+00
# 4            101.0              1.0       3900.0  1082816.0  1.002160e+09
#
#     NTA                                  Location
# 0   NaN                                       NaN
# 1  BK79  POINT (-73.917234675717 40.683186288397)
# 2  MN17  POINT (-73.977755548006 40.753276954279)
# 3   NaN                                       NaN
# 4  MN24  POINT (-74.010097618713 40.720651658088)
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Missing Values Analysis

# %%
# Display statistical summary
print("Statistical Summary:")
df.describe()
# Out:
# Statistical Summary:
#               CAMIS        ZIPCODE          SCORE       Latitude  \
# count  2.972910e+05  294119.000000  280761.000000  295888.000000
# mean   4.805603e+07   10707.228734      25.166512      40.295172
# std    3.759259e+06     616.043241      18.736489       4.177797
# min    3.007544e+07    6605.000000       0.000000       0.000000
# 25%    5.000413e+07   10023.000000      12.000000      40.686617
# 50%    5.009185e+07   11101.000000      21.000000      40.732728
# 75%    5.012984e+07   11232.000000      33.000000      40.761191
# max    5.018219e+07   69361.000000     203.000000      40.912822
#
#            Longitude  Community Board  Council District   Census Tract  \
# count  295888.000000    292742.000000     292769.000000  292769.000000
# mean      -73.154175       254.964132         20.573862   29909.072706
# std         7.584000       130.380962         15.673504   31325.914329
# min       -74.249101       101.000000          1.000000     100.000000
# 25%       -73.988629       106.000000          4.000000    8000.000000
# 50%       -73.955728       302.000000         20.000000   17300.000000
# 75%       -73.893827       402.000000         34.000000   42600.000000
# max         0.000000       595.000000         51.000000  162100.000000
#
#                 BIN           BBL
# count  2.915010e+05  2.958880e+05
# mean   2.586353e+06  2.479064e+09
# std    1.356201e+06  1.338338e+09
# min    1.000000e+06  1.000000e+00
# 25%    1.051454e+06  1.011110e+09
# 50%    3.022064e+06  3.008070e+09
# 75%    4.011502e+06  4.006300e+09
# max    5.799501e+06  5.270001e+09

# %% [markdown]
# ## Statistical Summary

# %%
print(f"Shape: {df.shape}")
# Out:
# Shape: (297291, 27)

# %%
# Display data types and info
print("\nData Types and Info:")
df.info()
# Out:
# Data Types and Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 297291 entries, 0 to 297290
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   CAMIS                  297291 non-null  int64
#  1   DBA                    297289 non-null  str
#  2   BORO                   297291 non-null  str
#  3   BUILDING               296322 non-null  str
#  4   STREET                 297290 non-null  str
#  5   ZIPCODE                294119 non-null  float64
#  6   PHONE                  297279 non-null  str
#  7   CUISINE DESCRIPTION    294071 non-null  str
#  8   INSPECTION DATE        297291 non-null  str
#  9   ACTION                 294071 non-null  str
#  10  VIOLATION CODE         291769 non-null  str
#  11  VIOLATION DESCRIPTION  291768 non-null  str
#  12  CRITICAL FLAG          297291 non-null  str
#  13  SCORE                  280761 non-null  float64
#  14  GRADE                  146614 non-null  str
#  15  GRADE DATE             137122 non-null  str
#  16  RECORD DATE            297291 non-null  str
#  17  INSPECTION TYPE        294071 non-null  str
#  18  Latitude               295888 non-null  float64
#  19  Longitude              295888 non-null  float64
#  20  Community Board        292742 non-null  float64
#  21  Council District       292769 non-null  float64
#  22  Census Tract           292769 non-null  float64
#  23  BIN                    291501 non-null  float64
#  24  BBL                    295888 non-null  float64
#  25  NTA                    292742 non-null  str
#  26  Location               292742 non-null  str
# dtypes: float64(9), int64(1), str(17)
# memory usage: 61.2 MB

# %%
#See how many null values are in each column --zeek
print(df.isnull().sum())
# Out:
# CAMIS                         0
# DBA                           2
# BORO                          0
# BUILDING                    969
# STREET                        1
# ZIPCODE                    3172
# PHONE                        12
# CUISINE DESCRIPTION        3220
# INSPECTION DATE               0
# ACTION                     3220
# VIOLATION CODE             5522
# VIOLATION DESCRIPTION      5523
# CRITICAL FLAG                 0
# SCORE                     16530
# GRADE                    150677
# GRADE DATE               160169
# RECORD DATE                   0
# INSPECTION TYPE            3220
# Latitude                   1403
# Longitude                  1403
# Community Board            4549
# Council District           4522
# Census Tract               4522
# BIN                        5790
# BBL                        1403
# NTA                        4549
# Location                   4549
# dtype: int64

# %%
#get rid of nulls
def clean_restaurant_inspection_data(df):
    # Make a copy to avoid modifying original
    df_clean = df.copy()
    
    # Basic info cleaning
    df_clean['DBA'] = df_clean['DBA'].fillna("Unknown Business")
    df_clean['BUILDING'] = df_clean['BUILDING'].fillna("No Number")
    df_clean['STREET'] = df_clean['STREET'].fillna("Unknown Street")
    df_clean['PHONE'] = df_clean['PHONE'].fillna("No Phone Listed")
    
    # Zipcode by borough
    df_clean['ZIPCODE'] = df_clean.groupby('BORO')['ZIPCODE'].transform(lambda x: x.fillna(x.median()))
    
    # Inspection related
    df_clean['CUISINE DESCRIPTION'] = df_clean['CUISINE DESCRIPTION'].fillna("Unspecified")
    df_clean['ACTION'] = df_clean['ACTION'].fillna("No Action Recorded")
    df_clean['INSPECTION TYPE'] = df_clean['INSPECTION TYPE'].fillna("Unspecified")
    df_clean['VIOLATION CODE'] = df_clean['VIOLATION CODE'].fillna("No Violation")
    df_clean['VIOLATION DESCRIPTION'] = df_clean['VIOLATION DESCRIPTION'].fillna("No Violation Found")
    
    # Grades and scores
    df_clean['SCORE'] = df_clean['SCORE'].fillna(-1)
    df_clean['GRADE'] = df_clean['GRADE'].fillna("Not Graded")
    df_clean['GRADE DATE'] = df_clean['GRADE DATE'].fillna(df_clean['INSPECTION DATE'])
    
    # Location data
    for coord in ['Latitude', 'Longitude']:
        df_clean[coord] = df_clean.groupby('BORO')[coord].transform(lambda x: x.fillna(x.median()))
    
    # Administrative boundaries - FIX HERE
    admin_cols = ['Community Board', 'Council District', 'Census Tract', 'NTA']
    for col in admin_cols:
        df_clean[col] = df_clean.groupby('BORO')[col].transform(lambda x: 
            x.fillna(x.mode().iloc[0] if not x.mode().empty else -1))
    
    # Building numbers
    df_clean['BIN'] = df_clean['BIN'].fillna(0)
    df_clean['BBL'] = df_clean['BBL'].fillna(0)
    
    # Location string
    df_clean['Location'] = df_clean['Location'].fillna('Unknown Location')
    
    return df_clean

# %%
# Import Required Libraries
# !pip install matplotlib
# !pip install seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 47.7 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 40.7 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 41.7 MB/s  0:00:00
# Downloading pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 51.8 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.1.1 pyparsing-3.3.2
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (2.4.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Convert INSPECTION DATE to datetime
df["INSPECTION DATE"] = pd.to_datetime(df["INSPECTION DATE"], errors="coerce")

# Filter data between 2015 and 2025
df_2015_2025 = df[
    (df["INSPECTION DATE"].dt.year >= 2015) &
    (df["INSPECTION DATE"].dt.year <= 2025)
].copy()

# %%
print("Original:", df.shape)
print("2015–2025:", df_2015_2025.shape)

print(
    df_2015_2025["INSPECTION DATE"].min(),
    "to",
    df_2015_2025["INSPECTION DATE"].max()
)
# Out:
# Original: (297291, 27)
# 2015–2025: (281111, 27)
# 2015-02-11 00:00:00 to 2025-12-31 00:00:00

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.countplot(data=df_2015_2025, x="GRADE", order=["A","B","C"])

plt.title("Distribution of Inspection Grades (2015–2025)")
plt.xlabel("Grade")
plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=df_2015_2025,
    x="BORO",
    hue="GRADE",
    order=df_2015_2025["BORO"].value_counts().index
)

plt.title("Inspection Grades by Borough")
plt.xlabel("Borough")
plt.ylabel("Count")
plt.legend(title="Grade")

plt.show()

# %%
df_2015_2025["YearMonth"] = df_2015_2025["INSPECTION DATE"].dt.to_period("M")

monthly = df_2015_2025.groupby("YearMonth")["CAMIS"].count()

plt.figure(figsize=(12,5))
monthly.plot()

plt.title("Inspection Volume Over Time (2015–2025)")
plt.xlabel("Year")
plt.ylabel("Number of Inspections")

plt.show()

# %%
plt.figure(figsize=(6,4))

sns.boxplot(
    data=df_2015_2025,
    x="GRADE",
    y="SCORE",
    order=["A","B","C"]
)

plt.title("Inspection Scores by Grade")
plt.xlabel("Grade")
plt.ylabel("Score")

plt.show()

# %%
#Histogram of Grade
plt.hist(df_2015_2025.SCORE)
# Out:
# (array([1.30314e+05, 9.39760e+04, 3.01900e+04, 9.70500e+03, 2.88500e+03,
#         9.81000e+02, 4.59000e+02, 6.10000e+01, 5.20000e+01, 1.00000e+01]),
#  array([  0. ,  20.3,  40.6,  60.9,  81.2, 101.5, 121.8, 142.1, 162.4,
#         182.7, 203. ]),
#  <BarContainer object of 10 artists>)

# %%
df.BORO.unique()
df_Manhatten = df[df['BORO'] == 'Manhattan'].copy()
df_Manhatten.describe()
# Out:
#               CAMIS        ZIPCODE             INSPECTION DATE          SCORE  \
# count  1.100400e+05  108425.000000                      110040  103117.000000
# mean   4.792802e+07   10022.686991  2022-08-29 08:39:26.499454      24.339459
# min    3.019184e+07   10000.000000         1900-01-01 00:00:00       0.000000
# 25%    5.000124e+07   10010.000000         2023-05-10 00:00:00      12.000000
# 50%    5.008947e+07   10017.000000         2024-06-27 00:00:00      20.000000
# 75%    5.012849e+07   10027.000000         2025-05-02 00:00:00      32.000000
# max    5.018219e+07   11371.000000         2026-02-20 00:00:00     203.000000
# std    3.850840e+06      31.298274                         NaN      18.560915
#
#             Latitude      Longitude  Community Board  Council District  \
# count  109530.000000  109530.000000    107915.000000     107915.000000
# mean       40.153195     -72.890597       105.079535          3.652690
# min         0.000000     -74.019624       101.000000          1.000000
# 25%        40.727813     -73.995191       103.000000          2.000000
# 50%        40.749855     -73.985473       105.000000          3.000000
# 75%        40.765893     -73.970914       107.000000          4.000000
# max        40.872885       0.000000       164.000000         10.000000
# std         4.912220       8.917024         3.045598          2.371698
#
#         Census Tract           BIN           BBL
# count  107915.000000  1.074520e+05  1.095300e+05
# mean    10082.946412  1.037307e+06  9.905539e+08
# min       201.000000  1.000000e+06  1.000000e+00
# 25%      4700.000000  1.010896e+06  1.004810e+09
# 50%      9200.000000  1.028620e+06  1.008580e+09
# 75%     13400.000000  1.061879e+06  1.012990e+09
# max     31704.000000  1.799161e+06  1.270000e+09
# std      6753.727409  3.621031e+04  1.380682e+08

# %%
#Grading in Manhatten


plt.figure(figsize=(6,4))

sns.boxplot(
    data=df_Manhatten,
    x="GRADE",
    y="SCORE",
    order=["A","B","C"]
)

plt.title("Inspection Scores by Grade (In Manhattan)")
plt.xlabel("Grade")
plt.ylabel("Score")

plt.show()
#Showing the boxplot throughout the years

# %%
df.BORO.unique()
df_Brooklyn = df[df['BORO'] == 'Brooklyn'].copy()
df_Brooklyn.describe()

plt.figure(figsize=(6,4))

sns.boxplot(
    data=df_Brooklyn,
    x="GRADE",
    y="SCORE",
    order=["A","B","C"]
)

plt.title("Inspection Scores by Grade (In Brooklyn)")
plt.xlabel("Grade")
plt.ylabel("Score")

plt.show()

# %%
df.BORO.unique()
df_Bronx = df[df['BORO'] == 'Bronx'].copy()
df_Bronx.describe()

plt.figure(figsize=(6,4))

sns.boxplot(
    data=df_Bronx,
    x="GRADE",
    y="SCORE",
    order=["A","B","C"]
)

plt.title("Inspection Scores by Grade (In The Bronx)")
plt.xlabel("Grade")
plt.ylabel("Score")

plt.show()

# %%
df.BORO.unique()
df_Queens = df[df['BORO'] == 'Queens'].copy()
df_Queens.describe()

plt.figure(figsize=(6,4))

sns.boxplot(
    data=df_Queens,
    x="GRADE",
    y="SCORE",
    order=["A","B","C"]
)

plt.title("Inspection Scores by Grade (In Queens)")
plt.xlabel("Grade")
plt.ylabel("Score")

plt.show()

# %%
df.BORO.unique()
df_Staten_Island = df[df['BORO'] == 'Staten Island'].copy()
df_Staten_Island.describe()

plt.figure(figsize=(6,4))

sns.boxplot(
    data=df_Staten_Island,
    x="GRADE",
    y="SCORE",
    order=["A","B","C"]
)

plt.title("Inspection Scores by Grade (In Staten Island)")
plt.xlabel("Grade")
plt.ylabel("Score")

plt.show()

# %% [markdown]
# Binary Features

# %% [markdown]
# Chain vs Independent

# %%
# !pip install pandas
import pandas as pd

# Create binary feature: Chain (1) vs Independent (0)
# A chain restaurant is identified by having multiple locations (same DBA appearing in different addresses)

# Count occurrences of each DBA
dba_counts = df['DBA'].value_counts()

# Restaurants appearing more than once are chains
chain_names = set(dba_counts[dba_counts > 1].index)

# Create the binary feature
df['is_chain'] = df['DBA'].apply(lambda x: 1 if x in chain_names else 0)

# Display results
print(f"Total restaurants: {len(df)}")
print(f"Chain restaurant records: {df['is_chain'].sum()}")
print(f"Independent restaurant records: {(df['is_chain'] == 0).sum()}")
print(f"\nChain vs Independent distribution:")
print(df['is_chain'].value_counts())
print(f"\nTop 10 chains by number of records:")
print(dba_counts.head(10))
# Out:
# Requirement already satisfied: pandas in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Total restaurants: 297291
# Chain restaurant records: 294304
# Independent restaurant records: 2987
#
# Chain vs Independent distribution:
# is_chain
# 1    294304
# 0      2987
# Name: count, dtype: int64
#
# Top 10 chains by number of records:
# DBA
# DUNKIN                    3203
# SUBWAY                    1951
# STARBUCKS                 1529
# MCDONALD'S                1428
# POPEYES                   1077
# DUNKIN'                    902
# BURGER KING                757
# KENNEDY FRIED CHICKEN      716
# CHIPOTLE MEXICAN GRILL     691
# DOMINO'S                   618
# Name: count, dtype: int64

# %%
# Get top 10 independent restaurants
independent_restaurants = dba_counts[~dba_counts.index.isin(chain_names)].head(10)

print("Top 10 Independent Restaurants (by number of inspection records):")
print("=" * 70)
for idx, (restaurant_name, count) in enumerate(independent_restaurants.items(), 1):
    print(f"{idx}. {restaurant_name}: {count} records")
# Out:
# Top 10 Independent Restaurants (by number of inspection records):
# ======================================================================
# 1. OLMO: 1 records
# 2. HUMAN RESOURCES (BERGAMOS): 1 records
# 3. PIER SIDE CAFE: 1 records
# 4. LAMBS BREAD DISPENSARY: 1 records
# 5. 84 UNI PL LLC: 1 records
# 6. Beresheet LLC: 1 records
# 7. CASA CARIBE: 1 records
# 8. SOFTBITE LIC LLC: 1 records
# 9. DELICIOUS SOUL FOOD: 1 records
# 10. PASCUAL MORAN: 1 records
