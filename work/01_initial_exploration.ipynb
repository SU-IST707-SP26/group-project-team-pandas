# %% [markdown]
# ## Uploading Data
# This notebook performs initial exploratory data analysis (EDA) on the restaurant inspection dataset to understand its structure, contents, and basic statistics.

# %%
# %pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 39.9 MB/s  0:00:006m0:00:01
# Downloading numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 44.8 MB/s  0:00:006m0:00:01
# Installing collected packages: numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/2 [numpy]  WARNING: The scripts f2py and numpy-config are installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# Successfully installed numpy-2.4.2 pandas-3.0.0
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# uploading data 
import pandas as pd

# NYC Open Data CSV download link
url = "https://data.cityofnewyork.us/api/views/43nn-pn8j/rows.csv?accessType=DOWNLOAD"

# Read directly from the web
df = pd.read_csv(url)

print("Shape:", df.shape)

# Preview
df.head()
# Out:
# Shape: (296270, 27)
#       CAMIS                  DBA           BORO BUILDING  \
# 0  50160505     STARBUCKS # 1955      Manhattan        0
# 1  50180152         Malta Coffee      Manhattan      250
# 2  50180331  NONG GENG JI 37 LLC         Queens   135-15
# 3  50165900    AFTER 5 WINGS INC  Staten Island       39
# 4  50179318  KOSHER BAY 2025 LLC       Brooklyn        2
#
#                       STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 0  JFK INTERNATIONAL AIRPORT      NaN  2299392549                 NaN
# 1           EAST   90 STREET  10128.0  9294089562                 NaN
# 2                  37 AVENUE  11354.0  6469441519                 NaN
# 3          VICTORY BOULEVARD  10301.0  7187994608                 NaN
# 4             NEPTUNE AVENUE  11235.0  3475548811                 NaN
#
#   INSPECTION DATE ACTION  ... INSPECTION TYPE   Latitude  Longitude  \
# 0      01/01/1900    NaN  ...             NaN   0.000000   0.000000
# 1      01/01/1900    NaN  ...             NaN  40.780892 -73.950990
# 2      01/01/1900    NaN  ...             NaN  40.761097 -73.832344
# 3      01/01/1900    NaN  ...             NaN  40.637756 -74.076645
# 4      01/01/1900    NaN  ...             NaN  40.583042 -73.954484
#
#    Community Board Council District Census Tract        BIN           BBL  \
# 0              NaN              NaN          NaN        NaN  1.000000e+00
# 1            108.0              5.0      15400.0  1048898.0  1.015350e+09
# 2            407.0             20.0      86900.0  4112261.0  4.049710e+09
# 3            501.0             49.0        300.0  5000062.0  5.000060e+09
# 4            315.0             48.0      61004.0  3245439.0  3.087108e+09
#
#     NTA                                  Location
# 0   NaN                                       NaN
# 1  MN32  POINT (-73.950989833247 40.780891880006)
# 2  QN22   POINT (-73.832343669087 40.76109723299)
# 3  SI22  POINT (-74.076644770718 40.637756207995)
# 4  BK19  POINT (-73.954483696012 40.583041776808)
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Missing Values Analysis

# %%
# Display statistical summary
print("Statistical Summary:")
df.describe()
# Out:
# Statistical Summary:
#               CAMIS        ZIPCODE          SCORE       Latitude  \
# count  2.962700e+05  293134.000000  279885.000000  294905.000000
# mean   4.804123e+07   10706.689534      25.149272      40.296535
# std    3.768163e+06     615.628413      18.755325       4.171505
# min    3.007544e+07    6605.000000       0.000000       0.000000
# 25%    5.000350e+07   10023.000000      12.000000      40.686746
# 50%    5.009103e+07   11101.000000      21.000000      40.732844
# 75%    5.012930e+07   11232.000000      33.000000      40.761214
# max    5.018167e+07   69361.000000     203.000000      40.912822
#
#            Longitude  Community Board  Council District   Census Tract  \
# count  294905.000000    291779.000000     291806.000000  291806.000000
# mean      -73.156605       254.807930         20.550989   29886.241870
# std         7.572572       130.403562         15.671797   31321.374378
# min       -74.249101       101.000000          1.000000     100.000000
# 25%       -73.988659       106.000000          4.000000    8000.000000
# 50%       -73.955805       302.000000         20.000000   17300.000000
# 75%       -73.893909       401.000000         34.000000   42600.000000
# max         0.000000       595.000000         51.000000  162100.000000
#
#                 BIN           BBL
# count  2.905310e+05  2.949050e+05
# mean   2.584650e+06  2.477503e+09
# std    1.356354e+06  1.338518e+09
# min    1.000000e+06  1.000000e+00
# 25%    1.050721e+06  1.010910e+09
# 50%    3.021604e+06  3.007930e+09
# 75%    4.011497e+06  4.006290e+09
# max    5.799501e+06  5.270001e+09

# %% [markdown]
# ## Statistical Summary

# %%
print(f"Shape: {df.shape}")
# Out:
# Shape: (296270, 27)

# %%
# Display data types and info
print("\nData Types and Info:")
df.info()
# Out:
# Data Types and Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 296270 entries, 0 to 296269
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   CAMIS                  296270 non-null  int64
#  1   DBA                    296268 non-null  str
#  2   BORO                   296270 non-null  str
#  3   BUILDING               295289 non-null  str
#  4   STREET                 296269 non-null  str
#  5   ZIPCODE                293134 non-null  float64
#  6   PHONE                  296261 non-null  str
#  7   CUISINE DESCRIPTION    293060 non-null  str
#  8   INSPECTION DATE        296270 non-null  str
#  9   ACTION                 293060 non-null  str
#  10  VIOLATION CODE         290768 non-null  str
#  11  VIOLATION DESCRIPTION  290767 non-null  str
#  12  CRITICAL FLAG          296270 non-null  str
#  13  SCORE                  279885 non-null  float64
#  14  GRADE                  146172 non-null  str
#  15  GRADE DATE             136768 non-null  str
#  16  RECORD DATE            296270 non-null  str
#  17  INSPECTION TYPE        293060 non-null  str
#  18  Latitude               294905 non-null  float64
#  19  Longitude              294905 non-null  float64
#  20  Community Board        291779 non-null  float64
#  21  Council District       291806 non-null  float64
#  22  Census Tract           291806 non-null  float64
#  23  BIN                    290531 non-null  float64
#  24  BBL                    294905 non-null  float64
#  25  NTA                    291779 non-null  str
#  26  Location               291779 non-null  str
# dtypes: float64(9), int64(1), str(17)
# memory usage: 61.0 MB

# %%
#See how many null values are in each column --zeek
print(df.isnull().sum())

"""#Get rid of null values
# !pip install scikit-learn
from sklearn.impute import SimpleImputer
import pandas as pd
import numpy as np

#columns we want to impute
cols_to_impute = ['Age', 'Income', 'Last_Purchase_Amount']

# store SimpleImputer in a variable for later use
imp = SimpleImputer(strategy='most_frequent')

# Fit and transform only the selected columns
df[cols_to_impute] = imp.fit_transform(df[cols_to_impute])

# Verify the amount of nulls in our columns
print("\nNull values after imputation:")
print(df[cols_to_impute].isnull().sum())"""
# Out:
# CAMIS                         0
# DBA                           2
# BORO                          0
# BUILDING                    981
# STREET                        1
# ZIPCODE                    3136
# PHONE                         9
# CUISINE DESCRIPTION        3210
# INSPECTION DATE               0
# ACTION                     3210
# VIOLATION CODE             5502
# VIOLATION DESCRIPTION      5503
# CRITICAL FLAG                 0
# SCORE                     16385
# GRADE                    150098
# GRADE DATE               159502
# RECORD DATE                   0
# INSPECTION TYPE            3210
# Latitude                   1365
# Longitude                  1365
# Community Board            4491
# Council District           4464
# Census Tract               4464
# BIN                        5739
# BBL                        1365
# NTA                        4491
# Location                   4491
# dtype: int64

# %%
# Import Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 4
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
#       7 # Set display options
#
# ModuleNotFoundError: No module named 'matplotlib'
