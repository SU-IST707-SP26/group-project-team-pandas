# %% [markdown]
# ## Uploading Data
# This notebook performs initial exploratory data analysis (EDA) on the restaurant inspection dataset to understand its structure, contents, and basic statistics.

# %%
# %pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 24.7 MB/s  0:00:00m0:00:01
# Installing collected packages: pandas
# Successfully installed pandas-3.0.1
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# uploading data 
import pandas as pd

# NYC Open Data CSV download link
url = "https://data.cityofnewyork.us/api/views/43nn-pn8j/rows.csv?accessType=DOWNLOAD"

# Read directly from the web
df = pd.read_csv(url)

print("Shape:", df.shape)

# Preview
df.head()
# Out:
# Shape: (296599, 27)
# /tmp/ipykernel_19539/703061283.py:8: DtypeWarning: Columns (0: PHONE) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)
#       CAMIS                 DBA       BORO  BUILDING                 STREET  \
# 0  50178186       PRET A MANGER     Queens       NaN      JFK TERMINAL    8
# 1  50167590  RY RYS KITCHEN LLC   Brooklyn      1140           UTICA AVENUE
# 2  50179663           TAXI CAFE     Queens  BLDG 187  CENTRAL TAXI HOLD LOT
# 3  50180830           LILY POND  Manhattan       183       WEST   10 STREET
# 4  50103070    SUSHI YOU GARDEN     Queens    215-05              73 AVENUE
#
#    ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  11430.0  6464760498                 NaN      01/01/1900
# 1  11203.0   176155981                 NaN      01/01/1900
# 2  11430.0  8455855146                 NaN      01/01/1900
# 3  10014.0  9178549168                 NaN      01/01/1900
# 4  11364.0  7182811188            Japanese      03/23/2023
#
#                                               ACTION  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                                                NaN  ...
# 3                                                NaN  ...
# 4  No violations were recorded at the time of thi...  ...
#
#                          INSPECTION TYPE   Latitude  Longitude  \
# 0                                    NaN        NaN        NaN
# 1                                    NaN  40.645015 -73.929675
# 2                                    NaN        NaN        NaN
# 3                                    NaN  40.734280 -74.002804
# 4  Cycle Inspection / Initial Inspection  40.740584 -73.759067
#
#    Community Board Council District Census Tract        BIN           BBL  \
# 0              NaN              NaN          NaN        NaN           NaN
# 1            317.0             45.0      85000.0  3105284.0  3.047600e+09
# 2              NaN              NaN          NaN        NaN           NaN
# 3            102.0              3.0       7300.0  1078129.0  1.006110e+09
# 4            411.0             23.0     136700.0  4163155.0  4.076380e+09
#
#     NTA                                  Location
# 0   NaN                                       NaN
# 1  BK91  POINT (-73.929674564511 40.645014721871)
# 2   NaN                                       NaN
# 3  MN23  POINT (-74.002803665805 40.734279831343)
# 4  QN42  POINT (-73.759067226065 40.740584117577)
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Missing Values Analysis

# %%
# Display statistical summary
print("Statistical Summary:")
df.describe()
# Out:
# Statistical Summary:
#               CAMIS        ZIPCODE          SCORE       Latitude  \
# count  2.965990e+05  293435.000000  280042.000000  295193.000000
# mean   4.806010e+07   10706.724528      25.160165      40.295336
# std    3.756976e+06     616.108746      18.731849       4.177403
# min    3.007544e+07    6605.000000       0.000000       0.000000
# 25%    5.000428e+07   10023.000000      12.000000      40.686666
# 50%    5.009194e+07   11101.000000      21.000000      40.732844
# 75%    5.012990e+07   11232.000000      33.000000      40.761237
# max    5.018236e+07   69361.000000     203.000000      40.912822
#
#            Longitude  Community Board  Council District   Census Tract  \
# count  295193.000000    292055.000000     292082.000000  292082.000000
# mean      -73.154326       254.867915         20.562804   29882.115868
# std         7.583270       130.384852         15.669621   31294.345167
# min       -74.249101       101.000000          1.000000     100.000000
# 25%       -73.988620       106.000000          4.000000    8000.000000
# 50%       -73.955709       302.000000         20.000000   17300.000000
# 75%       -73.893885       402.000000         34.000000   42600.000000
# max         0.000000       595.000000         51.000000  162100.000000
#
#                 BIN           BBL
# count  2.908100e+05  2.951930e+05
# mean   2.585421e+06  2.478084e+09
# std    1.356298e+06  1.338401e+09
# min    1.000000e+06  1.000000e+00
# 25%    1.051453e+06  1.011110e+09
# 50%    3.021604e+06  3.008010e+09
# 75%    4.011502e+06  4.006290e+09
# max    5.799501e+06  5.270001e+09

# %% [markdown]
# ## Statistical Summary

# %%
print(f"Shape: {df.shape}")
# Out:
# Shape: (296599, 27)

# %%
# Display data types and info
print("\nData Types and Info:")
df.info()
# Out:
# Data Types and Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 296599 entries, 0 to 296598
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   CAMIS                  296599 non-null  int64
#  1   DBA                    296597 non-null  str
#  2   BORO                   296599 non-null  str
#  3   BUILDING               295634 non-null  str
#  4   STREET                 296598 non-null  str
#  5   ZIPCODE                293435 non-null  float64
#  6   PHONE                  296586 non-null  object
#  7   CUISINE DESCRIPTION    293332 non-null  str
#  8   INSPECTION DATE        296599 non-null  str
#  9   ACTION                 293332 non-null  str
#  10  VIOLATION CODE         291036 non-null  str
#  11  VIOLATION DESCRIPTION  291035 non-null  str
#  12  CRITICAL FLAG          296599 non-null  str
#  13  SCORE                  280042 non-null  float64
#  14  GRADE                  146281 non-null  str
#  15  GRADE DATE             136808 non-null  str
#  16  RECORD DATE            296599 non-null  str
#  17  INSPECTION TYPE        293332 non-null  str
#  18  Latitude               295193 non-null  float64
#  19  Longitude              295193 non-null  float64
#  20  Community Board        292055 non-null  float64
#  21  Council District       292082 non-null  float64
#  22  Census Tract           292082 non-null  float64
#  23  BIN                    290810 non-null  float64
#  24  BBL                    295193 non-null  float64
#  25  NTA                    292055 non-null  str
#  26  Location               292055 non-null  str
# dtypes: float64(9), int64(1), object(1), str(16)
# memory usage: 61.1+ MB

# %%
#See how many null values are in each column --zeek
print(df.isnull().sum())
# Out:
# CAMIS                         0
# DBA                           2
# BORO                          0
# BUILDING                    965
# STREET                        1
# ZIPCODE                    3164
# PHONE                        13
# CUISINE DESCRIPTION        3267
# INSPECTION DATE               0
# ACTION                     3267
# VIOLATION CODE             5563
# VIOLATION DESCRIPTION      5564
# CRITICAL FLAG                 0
# SCORE                     16557
# GRADE                    150318
# GRADE DATE               159791
# RECORD DATE                   0
# INSPECTION TYPE            3267
# Latitude                   1406
# Longitude                  1406
# Community Board            4544
# Council District           4517
# Census Tract               4517
# BIN                        5789
# BBL                        1406
# NTA                        4544
# Location                   4544
# dtype: int64

# %%
#get rid of nulls
def clean_restaurant_inspection_data(df):
    # Make a copy to avoid modifying original
    df_clean = df.copy()
    
    # Basic info cleaning
    df_clean['DBA'] = df_clean['DBA'].fillna("Unknown Business")
    df_clean['BUILDING'] = df_clean['BUILDING'].fillna("No Number")
    df_clean['STREET'] = df_clean['STREET'].fillna("Unknown Street")
    df_clean['PHONE'] = df_clean['PHONE'].fillna("No Phone Listed")
    
    # Zipcode by borough
    df_clean['ZIPCODE'] = df_clean.groupby('BORO')['ZIPCODE'].transform(lambda x: x.fillna(x.median()))
    
    # Inspection related
    df_clean['CUISINE DESCRIPTION'] = df_clean['CUISINE DESCRIPTION'].fillna("Unspecified")
    df_clean['ACTION'] = df_clean['ACTION'].fillna("No Action Recorded")
    df_clean['INSPECTION TYPE'] = df_clean['INSPECTION TYPE'].fillna("Unspecified")
    df_clean['VIOLATION CODE'] = df_clean['VIOLATION CODE'].fillna("No Violation")
    df_clean['VIOLATION DESCRIPTION'] = df_clean['VIOLATION DESCRIPTION'].fillna("No Violation Found")
    
    # Grades and scores
    df_clean['SCORE'] = df_clean['SCORE'].fillna(-1)
    df_clean['GRADE'] = df_clean['GRADE'].fillna("Not Graded")
    df_clean['GRADE DATE'] = df_clean['GRADE DATE'].fillna(df_clean['INSPECTION DATE'])
    
    # Location data
    for coord in ['Latitude', 'Longitude']:
        df_clean[coord] = df_clean.groupby('BORO')[coord].transform(lambda x: x.fillna(x.median()))
    
    # Administrative boundaries - FIX HERE
    admin_cols = ['Community Board', 'Council District', 'Census Tract', 'NTA']
    for col in admin_cols:
        df_clean[col] = df_clean.groupby('BORO')[col].transform(lambda x: 
            x.fillna(x.mode().iloc[0] if not x.mode().empty else -1))
    
    # Building numbers
    df_clean['BIN'] = df_clean['BIN'].fillna(0)
    df_clean['BBL'] = df_clean['BBL'].fillna(0)
    
    # Location string
    df_clean['Location'] = df_clean['Location'].fillna('Unknown Location')
    
    return df_clean

# %%
# Import Required Libraries
# !pip install matplotlib
# !pip install seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 44.5 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 39.1 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 31.9 MB/s  0:00:00
# Downloading pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 44.3 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.1.1 pyparsing-3.3.2
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (2.4.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# Our new filtered year
df["INSPECTION DATE"] = pd.to_datetime(df["INSPECTION DATE"], errors="coerce")

# Filter from 2022 to 2025
df_filtered_2022_2025 = df[
    (df["INSPECTION DATE"].dt.year >= 2022) &
    (df["INSPECTION DATE"].dt.year <= 2025)
]

# Check shape
print("Filtered Shape (2022–2025):", df_filtered_2022_2025.shape)

# Preview
df_filtered_2022_2025.head()
# Out:
# Filtered Shape (2022–2025): (275855, 27)
#        CAMIS               DBA       BORO BUILDING  \
# 4   50103070  SUSHI YOU GARDEN     Queens   215-05
# 6   41032752        DONS BOGAM  Manhattan     1517
# 11  50120802      ROSA'S PIZZA  Manhattan     2210
# 19  41510846    218 RESTAURANT  Manhattan   218220
# 22  50046726  CHIRPING CHICKEN  Manhattan      NaN
#
#                           STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 4                      73 AVENUE  11364.0  7182811188            Japanese
# 6               EAST   32 STREET      NaN  2126832200              Korean
# 11  FREDERICK DOUGLASS BOULEVARD      NaN  9174090099               Pizza
# 19                  GRAND STREET      NaN  2122268039             Chinese
# 22        GRAND CENTRAL TERMINAL  10017.0  6464765397            American
#
#    INSPECTION DATE  \
# 4       2023-03-23
# 6       2024-01-31
# 11      2025-09-03
# 19      2025-03-06
# 22      2024-03-20
#
#                                                          ACTION  \
# 4   No violations were recorded at the time of this inspection.
# 6               Violations were cited in the following area(s).
# 11              Violations were cited in the following area(s).
# 19              Violations were cited in the following area(s).
# 22              Violations were cited in the following area(s).
#
#    VIOLATION CODE  \
# 4             NaN
# 6             09B
# 11            02B
# 19            08A
# 22            04M
#
#                                                                                  VIOLATION DESCRIPTION  \
# 4                                                                                                  NaN
# 6                                                                          Thawing procedure improper.
# 11                                                      Hot TCS food item not held at or above 140 °F.
# 19  Establishment is not free of harborage or conditions conducive to rodents, insects or other pests.
# 22                                                   Live roaches in facility's food or non-food area.
#
#      CRITICAL FLAG  SCORE GRADE  GRADE DATE RECORD DATE  \
# 4   Not Applicable    0.0   NaN         NaN  02/27/2026
# 6     Not Critical   28.0   NaN         NaN  02/27/2026
# 11        Critical   13.0     A  09/03/2025  02/27/2026
# 19    Not Critical   31.0   NaN         NaN  02/27/2026
# 22        Critical   30.0     C  03/20/2024  02/27/2026
#
#                           INSPECTION TYPE   Latitude  Longitude  \
# 4   Cycle Inspection / Initial Inspection  40.740584 -73.759067
# 6   Cycle Inspection / Initial Inspection   0.000000   0.000000
# 11  Cycle Inspection / Initial Inspection   0.000000   0.000000
# 19  Cycle Inspection / Initial Inspection   0.000000   0.000000
# 22       Cycle Inspection / Re-inspection        NaN        NaN
#
#     Community Board  Council District  Census Tract        BIN           BBL  \
# 4             411.0              23.0      136700.0  4163155.0  4.076380e+09
# 6               NaN               NaN           NaN        NaN  1.000000e+00
# 11              NaN               NaN           NaN        NaN  1.000000e+00
# 19              NaN               NaN           NaN        NaN  1.000000e+00
# 22              NaN               NaN           NaN        NaN           NaN
#
#      NTA                                  Location
# 4   QN42  POINT (-73.759067226065 40.740584117577)
# 6    NaN                                       NaN
# 11   NaN                                       NaN
# 19   NaN                                       NaN
# 22   NaN                                       NaN

# %%
print("Original:", df.shape)
print("2022–2025:", df_filtered_2022_2025.shape)

print(
    df_filtered_2022_2025["INSPECTION DATE"].min(),
    "to",
    df_filtered_2022_2025["INSPECTION DATE"].max()
)
# Out:
# Original: (296599, 27)
# 2022–2025: (275855, 27)
# 2022-01-03 00:00:00 to 2025-12-31 00:00:00

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.countplot(data=df_filtered_2022_2025, x="GRADE", order=["A","B","C"])

plt.title("Distribution of Inspection Grades (2022–2025)")
plt.xlabel("Grade")
plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=df_filtered_2022_2025,
    x="BORO",
    hue="GRADE",
    order=df_filtered_2022_2025["BORO"].value_counts().index
)

plt.title("Inspection Grades by Borough")
plt.xlabel("Borough")
plt.ylabel("Count")
plt.legend(title="Grade")

plt.show()

# %%
df_filtered_2022_2025["YearMonth"] = df_filtered_2022_2025["INSPECTION DATE"].dt.to_period("M")

monthly = df_filtered_2022_2025.groupby("YearMonth")["CAMIS"].count()

plt.figure(figsize=(12,5))
monthly.plot()

plt.title("Inspection Volume Over Time (2022–2025)")
plt.xlabel("Year")
plt.ylabel("Number of Inspections")

plt.show()

# %%
plt.figure(figsize=(6,4))

sns.boxplot(
    data=df_filtered_2022_2025,
    x="GRADE",
    y="SCORE",
    order=["A","B","C"]
)

plt.title("Inspection Scores by Grade")
plt.xlabel("Grade")
plt.ylabel("Score")

plt.show()

# %%
#Histogram of Grade
plt.hist(df_filtered_2022_2025.SCORE)
# Out:
# (array([1.27485e+05, 9.23990e+04, 2.97710e+04, 9.55100e+03, 2.86400e+03,
#         9.89000e+02, 4.40000e+02, 6.10000e+01, 5.20000e+01, 1.00000e+01]),
#  array([  0. ,  20.3,  40.6,  60.9,  81.2, 101.5, 121.8, 142.1, 162.4,
#         182.7, 203. ]),
#  <BarContainer object of 10 artists>)

# %%
df.BORO.unique()
df_Manhattan = df_filtered_2022_2025[df_filtered_2022_2025['BORO'] == 'Manhattan'].copy()
df_Manhattan.describe()
# Out:
#               CAMIS        ZIPCODE             INSPECTION DATE         SCORE  \
# count  1.019630e+05  100562.000000                      101963  96937.000000
# mean   4.790401e+07   10022.630467  2024-05-04 01:22:12.518658     24.372716
# min    3.019184e+07   10000.000000         2022-01-03 00:00:00      0.000000
# 25%    5.000073e+07   10010.000000         2023-05-24 00:00:00     12.000000
# 50%    5.008769e+07   10017.000000         2024-06-18 00:00:00     20.000000
# 75%    5.012616e+07   10027.000000         2025-04-04 00:00:00     32.000000
# max    5.018002e+07   11371.000000         2025-12-31 00:00:00    203.000000
# std    3.864743e+06      31.413821                         NaN     18.660984
#
#             Latitude      Longitude  Community Board  Council District  \
# count  101525.000000  101525.000000    100124.000000     100124.000000
# mean       40.191684     -72.960497       105.083956          3.652081
# min         0.000000     -74.018001       101.000000          1.000000
# 25%        40.727809     -73.995209       103.000000          2.000000
# 50%        40.749801     -73.985485       105.000000          3.000000
# 75%        40.766065     -73.970862       107.000000          4.000000
# max        40.872885       0.000000       164.000000         10.000000
# std         4.754440       8.630602         3.055291          2.371400
#
#         Census Tract           BIN           BBL
# count  100124.000000  9.970700e+04  1.015250e+05
# mean    10071.037234  1.037321e+06  9.916229e+08
# min       201.000000  1.000000e+06  1.000000e+00
# 25%      4700.000000  1.010919e+06  1.004800e+09
# 50%      9200.000000  1.028646e+06  1.008580e+09
# 75%     13400.000000  1.061828e+06  1.013010e+09
# max     31704.000000  1.799161e+06  1.270000e+09
# std      6737.712151  3.611711e+04  1.342235e+08

# %%
#Grading in Manhattan


plt.figure(figsize=(6,4))

sns.boxplot(
    data=df_Manhattan,
    x="GRADE",
    y="SCORE",
    order=["A","B","C"]
)

plt.title("Inspection Scores by Grade (In Manhattan)")
plt.xlabel("Grade")
plt.ylabel("Score")

plt.show()
#Showing the boxplot throughout the years

# %%
df.BORO.unique()
df_Brooklyn = df_filtered_2022_2025[df_filtered_2022_2025['BORO'] == 'Brooklyn'].copy()
df_Brooklyn.describe()

plt.figure(figsize=(6,4))

sns.boxplot(
    data=df_Brooklyn,
    x="GRADE",
    y="SCORE",
    order=["A","B","C"]
)

plt.title("Inspection Scores by Grade (In Brooklyn)")
plt.xlabel("Grade")
plt.ylabel("Score")

plt.show()

# %%
df.BORO.unique()
df_Bronx = df_filtered_2022_2025[df_filtered_2022_2025['BORO'] == 'Bronx'].copy()
df_Bronx.describe()

plt.figure(figsize=(6,4))

sns.boxplot(
    data=df_Bronx,
    x="GRADE",
    y="SCORE",
    order=["A","B","C"]
)

plt.title("Inspection Scores by Grade (In The Bronx)")
plt.xlabel("Grade")
plt.ylabel("Score")

plt.show()

# %%
df.BORO.unique()
df_Queens = df_filtered_2022_2025[df_filtered_2022_2025['BORO'] == 'Queens'].copy()
df_Queens.describe()

plt.figure(figsize=(6,4))

sns.boxplot(
    data=df_Queens,
    x="GRADE",
    y="SCORE",
    order=["A","B","C"]
)

plt.title("Inspection Scores by Grade (In Queens)")
plt.xlabel("Grade")
plt.ylabel("Score")

plt.show()

# %%
df.BORO.unique()
df_Staten_Island = df_filtered_2022_2025[df_filtered_2022_2025['BORO'] == 'Staten Island'].copy()
df_Staten_Island.describe()

plt.figure(figsize=(6,4))

sns.boxplot(
    data=df_Staten_Island,
    x="GRADE",
    y="SCORE",
    order=["A","B","C"]
)

plt.title("Inspection Scores by Grade (In Staten Island)")
plt.xlabel("Grade")
plt.ylabel("Score")

plt.show()

# %% [markdown]
# Binary Features

# %% [markdown]
# Chain vs Independent

# %% [markdown]
# !pip install pandas
# import pandas as pd
#
# # Create binary feature: Chain (1) vs Independent (0)
# # A chain restaurant is identified by having multiple locations (same DBA appearing in different addresses)
#
# # Count occurrences of each DBA
# dba_counts = df['DBA'].value_counts()
#
# # Restaurants appearing more than once are chains
# chain_names = set(dba_counts[dba_counts > 1].index)
#
# # Create the binary feature
# df['is_chain'] = df['DBA'].apply(lambda x: 1 if x in chain_names else 0)
#
# # Display results
# print(f"Total restaurants: {len(df)}")
# print(f"Chain restaurant records: {df['is_chain'].sum()}")
# print(f"Independent restaurant records: {(df['is_chain'] == 0).sum()}")
# print(f"\nChain vs Independent distribution:")
# print(df['is_chain'].value_counts())
# print(f"\nTop 10 chains by number of records:")
# print(dba_counts.head(10))

# %% [markdown]
# # Get top 10 independent restaurants
# independent_restaurants = dba_counts[~dba_counts.index.isin(chain_names)].head(10)
#
# print("Top 10 Independent Restaurants (by number of inspection records):")
# print("=" * 70)
# for idx, (restaurant_name, count) in enumerate(independent_restaurants.items(), 1):
#     print(f"{idx}. {restaurant_name}: {count} records")

# %% [markdown]
# Fixing chain

# %%
# Clean DBA names to reduce formatting duplicates
df_filtered_2022_2025['DBA_clean'] = (
    df_filtered_2022_2025['DBA']
    .str.upper()
    .str.strip()
)

# Count unique restaurant locations (CAMIS) per DBA
dba_unique_locations = (
    df_filtered_2022_2025
    .groupby('DBA_clean')['CAMIS']
    .nunique()
)

# Identify chains as DBAs with more than one unique location
chain_names = set(dba_unique_locations[dba_unique_locations > 1].index)

# Create binary feature: 1 = chain, 0 = independent
df_filtered_2022_2025['is_chain'] = (
    df_filtered_2022_2025['DBA_clean']
    .isin(chain_names)
    .astype(int)
)

# Create numeric feature for chain size
df_filtered_2022_2025['chain_size'] = (
    df_filtered_2022_2025['DBA_clean']
    .map(dba_unique_locations)
)

# Display summary
print("Chain vs Independent distribution:")
print(df_filtered_2022_2025['is_chain'].value_counts())

print("\nTop 10 chains by number of locations:")
print(dba_unique_locations.sort_values(ascending=False).head(10))
# Out:
# Chain vs Independent distribution:
# is_chain
# 0    201434
# 1     74421
# Name: count, dtype: int64
#
# Top 10 chains by number of locations:
# DBA_clean
# DUNKIN                    348
# STARBUCKS                 202
# SUBWAY                    170
# MCDONALD'S                165
# POPEYES                   123
# DUNKIN'                    97
# CHIPOTLE MEXICAN GRILL     72
# DOMINO'S                   71
# TACO BELL                  68
# BURGER KING                65
# Name: CAMIS, dtype: int64

# %%
# !pip install scikit-learn

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

cat_cols = ["INSPECTION TYPE","BORO"]
# newer sklearn uses sparse_output instead of sparse

ohe = OneHotEncoder(handle_unknown="ignore", sparse_output=False)

preproc = ColumnTransformer(
    transformers=[
        ("cat", ohe, cat_cols),
    ],
    remainder="passthrough"
)

# fit_transform on a subset (example)
X = df_filtered_2022_2025[cat_cols]
X_enc = preproc.fit_transform(X)
print("Transformed shape:", X_enc.shape)
print("Feature names:", preproc.get_feature_names_out())
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-learn) (2.4.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Using cached scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn-1.8.0
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Transformed shape: (275855, 39)
# Feature names: ['cat__INSPECTION TYPE_Administrative Miscellaneous / Compliance Inspection'
#  'cat__INSPECTION TYPE_Administrative Miscellaneous / Initial Inspection'
#  'cat__INSPECTION TYPE_Administrative Miscellaneous / Re-inspection'
#  'cat__INSPECTION TYPE_Administrative Miscellaneous / Reopening Inspection'
#  'cat__INSPECTION TYPE_Administrative Miscellaneous / Second Compliance Inspection'
#  'cat__INSPECTION TYPE_Calorie Posting / Compliance Inspection'
#  'cat__INSPECTION TYPE_Calorie Posting / Initial Inspection'
#  'cat__INSPECTION TYPE_Calorie Posting / Re-inspection'
#  'cat__INSPECTION TYPE_Cycle Inspection / Compliance Inspection'
#  'cat__INSPECTION TYPE_Cycle Inspection / Initial Inspection'
#  'cat__INSPECTION TYPE_Cycle Inspection / Re-inspection'
#  'cat__INSPECTION TYPE_Cycle Inspection / Reopening Inspection'
#  'cat__INSPECTION TYPE_Cycle Inspection / Second Compliance Inspection'
#  'cat__INSPECTION TYPE_Inter-Agency Task Force / Initial Inspection'
#  'cat__INSPECTION TYPE_Inter-Agency Task Force / Re-inspection'
#  'cat__INSPECTION TYPE_Pre-permit (Non-operational) / Compliance Inspection'
#  'cat__INSPECTION TYPE_Pre-permit (Non-operational) / Initial Inspection'
#  'cat__INSPECTION TYPE_Pre-permit (Non-operational) / Re-inspection'
#  'cat__INSPECTION TYPE_Pre-permit (Non-operational) / Second Compliance Inspection'
#  'cat__INSPECTION TYPE_Pre-permit (Operational) / Compliance Inspection'
#  'cat__INSPECTION TYPE_Pre-permit (Operational) / Initial Inspection'
#  'cat__INSPECTION TYPE_Pre-permit (Operational) / Re-inspection'
#  'cat__INSPECTION TYPE_Pre-permit (Operational) / Reopening Inspection'
#  'cat__INSPECTION TYPE_Pre-permit (Operational) / Second Compliance Inspection'
#  'cat__INSPECTION TYPE_Smoke-Free Air Act / Compliance Inspection'
#  'cat__INSPECTION TYPE_Smoke-Free Air Act / Initial Inspection'
#  'cat__INSPECTION TYPE_Smoke-Free Air Act / Re-inspection'
#  'cat__INSPECTION TYPE_Sodium Warning / Initial Inspection'
#  'cat__INSPECTION TYPE_Sodium Warning / Re-inspection'
#  'cat__INSPECTION TYPE_Trans Fat / Compliance Inspection'
#  'cat__INSPECTION TYPE_Trans Fat / Initial Inspection'
#  'cat__INSPECTION TYPE_Trans Fat / Re-inspection'
#  'cat__INSPECTION TYPE_Trans Fat / Second Compliance Inspection'
#  'cat__BORO_0' 'cat__BORO_Bronx' 'cat__BORO_Brooklyn'
#  'cat__BORO_Manhattan' 'cat__BORO_Queens' 'cat__BORO_Staten Island']

# %%
# Frequency encoding for violation codes
# calculate the frequency of each violation code in the filtered dataset

vc_counts = df_filtered_2022_2025['VIOLATION CODE'].value_counts()
# map counts back to the dataframe as a new column

df_filtered_2022_2025['violation_freq'] = df_filtered_2022_2025['VIOLATION CODE'].map(vc_counts)

# Optionally normalize to proportion

df_filtered_2022_2025['violation_freq_pct'] = (
    df_filtered_2022_2025['violation_freq'] / len(df_filtered_2022_2025)
)

print("Top 10 violation codes by frequency:")
print(vc_counts.head(10))
print(df_filtered_2022_2025[['VIOLATION CODE', 'violation_freq', 'violation_freq_pct']].head())
# Out:
# Top 10 violation codes by frequency:
# VIOLATION CODE
# 10F    38729
# 08A    25706
# 06D    17691
# 02G    17431
# 10B    17402
# 06C    16957
# 04L    14688
# 02B    14657
# 04N    11388
# 04A     7573
# Name: count, dtype: int64
#    VIOLATION CODE  violation_freq  violation_freq_pct
# 4             NaN             NaN                 NaN
# 6             09B          2691.0            0.009755
# 11            02B         14657.0            0.053133
# 19            08A         25706.0            0.093187
# 22            04M          5180.0            0.018778

# %%
# Target encoding for cuisine description
# use a numeric target (e.g. inspection score) or convert grade to numeric

# install helper package if not available
try:
    import category_encoders as ce
except ImportError:
    import sys
    # !{sys.executable} -m pip install category_encoders
    import category_encoders as ce

# choose the target column for encoding
target_col = "SCORE"  # or use "GRADE" after mapping grades to numbers

# build and apply the encoder
te = ce.TargetEncoder(cols=["CUISINE DESCRIPTION"], smoothing=0.3)

df_filtered_2022_2025["cuisine_te"] = te.fit_transform(
    df_filtered_2022_2025[["CUISINE DESCRIPTION"]],
    df_filtered_2022_2025[target_col],
)

# quick sanity check
print(df_filtered_2022_2025[["CUISINE DESCRIPTION", "cuisine_te"]].head())
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.9.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from category_encoders) (2.4.2)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from category_encoders) (3.0.1)
# Collecting patsy>=0.5.1 (from category_encoders)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: scikit-learn>=1.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from category_encoders) (1.8.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from category_encoders) (1.17.1)
# Collecting statsmodels>=0.9.0 (from category_encoders)
#   Downloading statsmodels-0.14.6-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-learn>=1.6.0->category_encoders) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels>=0.9.0->category_encoders) (25.0)
# Downloading category_encoders-2.9.0-py3-none-any.whl (85 kB)
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Downloading statsmodels-0.14.6-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 43.8 MB/s  0:00:006m0:00:01
# Installing collected packages: patsy, statsmodels, category_encoders
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [category_encoders]statsmodels]
# Successfully installed category_encoders-2.9.0 patsy-1.0.2 statsmodels-0.14.6
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 18
#      15 # build and apply the encoder
#      16 te = ce.TargetEncoder(cols=["CUISINE DESCRIPTION"], smoothing=0.3)
# ---> 18 df_filtered_2022_2025["cuisine_te"] = te.fit_transform(
#      19     df_filtered_2022_2025[["CUISINE DESCRIPTION"]],
#      20     df_filtered_2022_2025[target_col],
#      21 )
#      23 # quick sanity check
#      24 print(df_filtered_2022_2025[["CUISINE DESCRIPTION", "cuisine_te"]].head())
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/category_encoders/utils.py:643, in SupervisedTransformerMixin.fit_transform(self, X, y, **fit_params)
#     641 if y is None:
#     642     raise TypeError('fit_transform() missing argument: ' 'y' '')
# --> 643 return self.fit(X, y, **fit_params).transform(X, y)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/category_encoders/utils.py:453, in BaseEncoder.fit(self, X, y, **kwargs)
#     436 """Fits the encoder according to X and y.
#     437
#     438 Parameters
#    (...)    450
#     451 """
#     452 X, y = convert_inputs(X, y)
# --> 453 self._check_fit_inputs(X, y)
#     454 self.feature_names_in_ = X.columns.tolist()
#     455 self.n_features_in_ = len(self.feature_names_in_)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/category_encoders/utils.py:502, in BaseEncoder._check_fit_inputs(self, X, y)
#     500 else:
#     501     if y.isna().any():  # Target column should never have missing values
# --> 502         raise ValueError('The target column y must not contain missing values.')
#
# ValueError: The target column y must not contain missing values.
