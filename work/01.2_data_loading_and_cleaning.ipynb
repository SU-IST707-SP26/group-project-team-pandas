# %% [markdown]
# # 01 Data Loading and Cleaning
#
# This notebook loads the NYC restaurant inspection dataset, checks missingness and structure, and performs the initial cleaning and year filtering used throughout the project.

# %%
"""# Author: Jessica
# Loading packages used in this notebook

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt"""
# Out:
# '# Author: Jessica\n# Loading packages used in this notebook\n\nimport pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt'

# %%
# Author: Jessica
# Loading the raw inspection dataset so this notebook runs independently

"""df = pd.read_csv("https://data.cityofnewyork.us/api/views/43nn-pn8j/rows.csv?accessType=DOWNLOAD")
print(df.shape)
df.head()"""
# Out:
# 'df = pd.read_csv("https://data.cityofnewyork.us/api/views/43nn-pn8j/rows.csv?accessType=DOWNLOAD")\nprint(df.shape)\ndf.head()'

# %% [markdown]
# ## Uploading Data
# This notebook performs initial exploratory data analysis (EDA) on the restaurant inspection dataset to understand its structure, contents, and basic statistics.

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# uploading data 
import pandas as pd

# NYC Open Data CSV download link
url = "https://data.cityofnewyork.us/api/views/43nn-pn8j/rows.csv?accessType=DOWNLOAD"

# Read directly from the web
df = pd.read_csv(url)

print("Shape:", df.shape)

# Preview
df.head()
# Out:
# Shape: (295481, 27)
#       CAMIS                             DBA       BORO BUILDING  \
# 0  50182613  RA @ CITADEL CONFERENCE CENTER  Manhattan      660
# 1  50180507                 LINCOLN STATION   Brooklyn      170
# 2  50150846                       ALTA GAMA     Queens   182-13
# 3  50127838                PAPA JOHNS PIZZA          0     2175
# 4  50146994                      MANGOS 960   Brooklyn      960
#
#            STREET  ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0        5 AVENUE  10103.0  7043286780                 NaN      01/01/1900
# 1        7 AVENUE  11215.0  9173316738                 NaN      01/01/1900
# 2  JAMAICA AVENUE  11423.0  5166889929                 NaN      01/01/1900
# 3      HYLAN BLVD  10306.0  9173026461               Pizza      05/15/2023
# 4        3 AVENUE  11232.0  3476059623                 NaN      01/01/1900
#
#                                             ACTION  ...  \
# 0                                              NaN  ...
# 1                                              NaN  ...
# 2                                              NaN  ...
# 3  Violations were cited in the following area(s).  ...
# 4                                              NaN  ...
#
#                          INSPECTION TYPE   Latitude  Longitude  \
# 0                                    NaN  40.760136 -73.976862
# 1                                    NaN  40.671804 -73.977494
# 2                                    NaN  40.708809 -73.778487
# 3  Cycle Inspection / Initial Inspection        NaN        NaN
# 4                                    NaN  40.655214 -74.006758
#
#    Community Board Council District Census Tract        BIN           BBL  \
# 0            105.0              4.0      10400.0  1034520.0  1.012688e+09
# 1            306.0             39.0      15700.0  3020693.0  3.009660e+09
# 2            412.0             23.0      47000.0  4211802.0  4.099000e+09
# 3              NaN              NaN          NaN        NaN           NaN
# 4            307.0             38.0        200.0  3010309.0  3.006950e+09
#
#     NTA                                  Location
# 0  MN17  POINT (-73.976861645763 40.760135931218)
# 1  BK37  POINT (-73.977494431408 40.671803926156)
# 2  QN61  POINT (-73.778486916138 40.708808565609)
# 3   NaN                                       NaN
# 4  BK32  POINT (-74.006757553487 40.655213753083)
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Missing Values Analysis

# %%
# Display statistical summary
print("Statistical Summary:")
df.describe()
# Out:
# Statistical Summary:
#               CAMIS        ZIPCODE          SCORE       Latitude  \
# count  2.954810e+05  292309.000000  278683.000000  293845.000000
# mean   4.808685e+07   10706.052622      25.237237      40.293023
# std    3.739469e+06     617.439878      18.817014       4.188854
# min    3.007544e+07    6605.000000       0.000000       0.000000
# 25%    5.000516e+07   10023.000000      12.000000      40.686884
# 50%    5.009363e+07   11101.000000      21.000000      40.732854
# 75%    5.013071e+07   11232.000000      33.000000      40.761186
# max    5.018365e+07   69361.000000     203.000000      40.912822
#
#            Longitude  Community Board  Council District   Census Tract  \
# count  293845.000000    290704.000000     290731.000000  290731.000000
# mean      -73.149921       254.809542         20.541717   29859.132308
# std         7.604041       130.354841         15.657899   31274.829909
# min       -74.249101       101.000000          1.000000     100.000000
# 25%       -73.988656       106.000000          4.000000    8000.000000
# 50%       -73.955714       302.000000         20.000000   17300.000000
# 75%       -73.893763       401.000000         34.000000   42600.000000
# max         0.000000       595.000000         51.000000  162100.000000
#
#                 BIN           BBL
# count  2.894830e+05  2.938450e+05
# mean   2.585051e+06  2.477644e+09
# std    1.355941e+06  1.337987e+09
# min    1.000000e+06  1.000000e+00
# 25%    1.051455e+06  1.010900e+09
# 50%    3.021640e+06  3.008020e+09
# 75%    4.011502e+06  4.006290e+09
# max    5.799501e+06  5.270001e+09

# %% [markdown]
# ## Statistical Summary

# %%
print(f"Shape: {df.shape}")
# Out:
# Shape: (295481, 27)

# %%
# Display data types and info
print("\nData Types and Info:")
df.info()
# Out:
# Data Types and Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 295481 entries, 0 to 295480
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   CAMIS                  295481 non-null  int64
#  1   DBA                    295480 non-null  str
#  2   BORO                   295481 non-null  str
#  3   BUILDING               294496 non-null  str
#  4   STREET                 295476 non-null  str
#  5   ZIPCODE                292309 non-null  float64
#  6   PHONE                  295408 non-null  str
#  7   CUISINE DESCRIPTION    292006 non-null  str
#  8   INSPECTION DATE        295481 non-null  str
#  9   ACTION                 292056 non-null  str
#  10  VIOLATION CODE         289754 non-null  str
#  11  VIOLATION DESCRIPTION  289754 non-null  str
#  12  CRITICAL FLAG          295481 non-null  str
#  13  SCORE                  278683 non-null  float64
#  14  GRADE                  145515 non-null  str
#  15  GRADE DATE             136122 non-null  str
#  16  RECORD DATE            295481 non-null  str
#  17  INSPECTION TYPE        292056 non-null  str
#  18  Latitude               293845 non-null  float64
#  19  Longitude              293845 non-null  float64
#  20  Community Board        290704 non-null  float64
#  21  Council District       290731 non-null  float64
#  22  Census Tract           290731 non-null  float64
#  23  BIN                    289483 non-null  float64
#  24  BBL                    293845 non-null  float64
#  25  NTA                    290704 non-null  str
#  26  Location               290704 non-null  str
# dtypes: float64(9), int64(1), str(17)
# memory usage: 60.9 MB

# %%
#See how many null values are in each column --zeek
print(df.isnull().sum())
# Out:
# CAMIS                         0
# DBA                           1
# BORO                          0
# BUILDING                    985
# STREET                        5
# ZIPCODE                    3172
# PHONE                        73
# CUISINE DESCRIPTION        3475
# INSPECTION DATE               0
# ACTION                     3425
# VIOLATION CODE             5727
# VIOLATION DESCRIPTION      5727
# CRITICAL FLAG                 0
# SCORE                     16798
# GRADE                    149966
# GRADE DATE               159359
# RECORD DATE                   0
# INSPECTION TYPE            3425
# Latitude                   1636
# Longitude                  1636
# Community Board            4777
# Council District           4750
# Census Tract               4750
# BIN                        5998
# BBL                        1636
# NTA                        4777
# Location                   4777
# dtype: int64

# %%
#get rid of nulls
def clean_restaurant_inspection_data(df):
    # Make a copy to avoid modifying original
    df_clean = df.copy()
    
    # Basic info cleaning
    df_clean['DBA'] = df_clean['DBA'].fillna("Unknown Business")
    df_clean['BUILDING'] = df_clean['BUILDING'].fillna("No Number")
    df_clean['STREET'] = df_clean['STREET'].fillna("Unknown Street")
    df_clean['PHONE'] = df_clean['PHONE'].fillna("No Phone Listed")
    
    # Zipcode by borough
    df_clean['ZIPCODE'] = df_clean.groupby('BORO')['ZIPCODE'].transform(lambda x: x.fillna(x.median()))
    
    # Inspection related
    df_clean['CUISINE DESCRIPTION'] = df_clean['CUISINE DESCRIPTION'].fillna("Unspecified")
    df_clean['ACTION'] = df_clean['ACTION'].fillna("No Action Recorded")
    df_clean['INSPECTION TYPE'] = df_clean['INSPECTION TYPE'].fillna("Unspecified")
    df_clean['VIOLATION CODE'] = df_clean['VIOLATION CODE'].fillna("No Violation")
    df_clean['VIOLATION DESCRIPTION'] = df_clean['VIOLATION DESCRIPTION'].fillna("No Violation Found")
    
    # Grades and scores
    df_clean['SCORE'] = df_clean['SCORE'].fillna(-1)
    df_clean['GRADE'] = df_clean['GRADE'].fillna("Not Graded")
    df_clean['GRADE DATE'] = df_clean['GRADE DATE'].fillna(df_clean['INSPECTION DATE'])
    
    # Location data
    for coord in ['Latitude', 'Longitude']:
        df_clean[coord] = df_clean.groupby('BORO')[coord].transform(lambda x: x.fillna(x.median()))
    
    # Administrative boundaries - FIX HERE
    admin_cols = ['Community Board', 'Council District', 'Census Tract', 'NTA']
    for col in admin_cols:
        df_clean[col] = df_clean.groupby('BORO')[col].transform(lambda x: 
            x.fillna(x.mode().iloc[0] if not x.mode().empty else -1))
    
    # Building numbers
    df_clean['BIN'] = df_clean['BIN'].fillna(0)
    df_clean['BBL'] = df_clean['BBL'].fillna(0)
    
    # Location string
    df_clean['Location'] = df_clean['Location'].fillna('Unknown Location')
    
    return df_clean

# %%
# Import Required Libraries
# !pip install matplotlib
# !pip install seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.23 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 55.7 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 44.1 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 32.0 MB/s  0:00:00
# Downloading pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 50.1 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 pillow-12.1.1 pyparsing-3.3.2
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (2.4.3)
# Requirement already satisfied: pandas>=1.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Our new filtered year
df["INSPECTION DATE"] = pd.to_datetime(df["INSPECTION DATE"], errors="coerce")

# Filter from 2022 to 2025
df_filtered_2022_2025 = df[
    (df["INSPECTION DATE"].dt.year >= 2022) &
    (df["INSPECTION DATE"].dt.year <= 2025)
]

# Check shape
print("Filtered Shape (2022–2025):", df_filtered_2022_2025.shape)

# Preview
df_filtered_2022_2025.head()
# Out:
# Filtered Shape (2022–2025): (267870, 27)
#        CAMIS                   DBA       BORO BUILDING  \
# 3   50127838      PAPA JOHNS PIZZA          0     2175
# 9   41395426  CITI FIELD STAND 423     Queens      126
# 11  50088988              CITY ONE  Manhattan     2726
# 21  50110727    TAQUERIA AL PASTOR   Brooklyn      128
# 28  41510846        218 RESTAURANT  Manhattan   218220
#
#                           STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 3                     HYLAN BLVD  10306.0  9173026461               Pizza
# 9               Roosevelt Avenue      NaN  7185958100            American
# 11  FREDERICK DOUGLASS BOULEVARD      NaN  2123688818             Chinese
# 21                WYCKOFF AVENUE  11237.0  7184567696             Mexican
# 28                  GRAND STREET      NaN  2122268039             Chinese
#
#    INSPECTION DATE                                           ACTION  \
# 3       2023-05-15  Violations were cited in the following area(s).
# 9       2024-09-20  Violations were cited in the following area(s).
# 11      2023-08-31  Violations were cited in the following area(s).
# 21      2024-11-13                Establishment re-opened by DOHMH.
# 28      2025-03-06  Violations were cited in the following area(s).
#
#    VIOLATION CODE  \
# 3             10G
# 9             08A
# 11            04L
# 21            NaN
# 28            02B
#
#                                                                                                        VIOLATION DESCRIPTION  \
# 3   Dishwashing and ware washing: Cleaning and sanitizing of tableware, including dishes, utensils, and equipment deficient.
# 9                         Establishment is not free of harborage or conditions conducive to rodents, insects or other pests.
# 11                                                  Evidence of mice or live mice in establishment's food or non-food areas.
# 21                                                                                                                       NaN
# 28                                                                            Hot TCS food item not held at or above 140 °F.
#
#      CRITICAL FLAG  SCORE GRADE  GRADE DATE RECORD DATE  \
# 3     Not Critical   22.0   NaN         NaN  03/27/2026
# 9     Not Critical   12.0     A  09/20/2024  03/27/2026
# 11        Critical   15.0     B  08/31/2023  03/27/2026
# 21  Not Applicable    0.0     P  11/13/2024  03/27/2026
# 28        Critical   31.0   NaN         NaN  03/27/2026
#
#                             INSPECTION TYPE  Latitude  Longitude  \
# 3     Cycle Inspection / Initial Inspection       NaN        NaN
# 9     Cycle Inspection / Initial Inspection   0.00000   0.000000
# 11         Cycle Inspection / Re-inspection   0.00000   0.000000
# 21  Cycle Inspection / Reopening Inspection  40.70346 -73.917891
# 28    Cycle Inspection / Initial Inspection   0.00000   0.000000
#
#     Community Board  Council District  Census Tract        BIN           BBL  \
# 3               NaN               NaN           NaN        NaN           NaN
# 9               NaN               NaN           NaN        NaN  4.000000e+00
# 11              NaN               NaN           NaN        NaN  1.000000e+00
# 21            304.0              37.0       44300.0  3074248.0  3.032590e+09
# 28              NaN               NaN           NaN        NaN  1.000000e+00
#
#      NTA                                  Location
# 3    NaN                                       NaN
# 9    NaN                                       NaN
# 11   NaN                                       NaN
# 21  BK77  POINT (-73.917891065325 40.703459661728)
# 28   NaN                                       NaN

# %%
print("Original:", df.shape)
print("2022–2025:", df_filtered_2022_2025.shape)

print(
    df_filtered_2022_2025["INSPECTION DATE"].min(),
    "to",
    df_filtered_2022_2025["INSPECTION DATE"].max()
)
# Out:
# Original: (295481, 27)
# 2022–2025: (267870, 27)
# 2022-01-03 00:00:00 to 2025-12-31 00:00:00

# %% [markdown]
# ## Saved Output
#
# This notebook saves a cleaned version of the filtered dataset for use in later notebooks.

# %%
# Author: Jessica
# Creating shared_data folder if it doesn’t exist, then saving cleaned dataset

import os

os.makedirs("shared_data", exist_ok=True)

cleaned_path = "shared_data/cleaned_inspections.csv"
df_filtered_2022_2025.to_csv(cleaned_path, index=False)

print(f"Saved cleaned dataset to {cleaned_path}")
# Out:
# Saved cleaned dataset to shared_data/cleaned_inspections.csv
