# %% [markdown]
# # 01 Data Loading and Cleaning
#
# This notebook loads the NYC restaurant inspection dataset, checks missingness and structure, and performs the initial cleaning and year filtering used throughout the project.

# %%
"""# Author: Jessica
# Loading packages used in this notebook

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt"""
# Out:
# '# Author: Jessica\n# Loading packages used in this notebook\n\nimport pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt'

# %%
# Author: Jessica
# Loading the raw inspection dataset so this notebook runs independently

"""df = pd.read_csv("https://data.cityofnewyork.us/api/views/43nn-pn8j/rows.csv?accessType=DOWNLOAD")
print(df.shape)
df.head()"""
# Out:
# 'df = pd.read_csv("https://data.cityofnewyork.us/api/views/43nn-pn8j/rows.csv?accessType=DOWNLOAD")\nprint(df.shape)\ndf.head()'

# %% [markdown]
# ## Uploading Data
# This notebook performs initial exploratory data analysis (EDA) on the restaurant inspection dataset to understand its structure, contents, and basic statistics.

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.0.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# uploading data 
import pandas as pd

# NYC Open Data CSV download link
url = "https://data.cityofnewyork.us/api/views/43nn-pn8j/rows.csv?accessType=DOWNLOAD"

# Read directly from the web
df = pd.read_csv(url)

print("Shape:", df.shape)

# Preview
df.head()
# Out:
# Shape: (295616, 27)
# /tmp/ipykernel_18381/703061283.py:8: DtypeWarning: Columns (0: PHONE) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)
#       CAMIS              DBA       BORO BUILDING            STREET  ZIPCODE  \
# 0  50179767  CEDAR BROS CORP   Brooklyn      271  BAY RIDGE AVENUE  11220.0
# 1  50169023     CAFE BON AMI  Manhattan      139    ORCHARD STREET  10002.0
# 2  50182573             MAKO  Manhattan      424          5 AVENUE  10018.0
# 3  50176082    Tacos Supreme      Bronx     2482    HOFFMAN STREET  10458.0
# 4  50162803     MASTER PANDA  Manhattan      245  WEST   46 STREET  10036.0
#
#         PHONE CUISINE DESCRIPTION INSPECTION DATE ACTION  ... INSPECTION TYPE  \
# 0  6463397841                 NaN      01/01/1900    NaN  ...             NaN
# 1  2015395127                 NaN      01/01/1900    NaN  ...             NaN
# 2  3124934694                 NaN      01/01/1900    NaN  ...             NaN
# 3  9177315718                 NaN      01/01/1900    NaN  ...             NaN
# 4  9295056765                 NaN      01/01/1900    NaN  ...             NaN
#
#     Latitude  Longitude  Community Board Council District Census Tract  \
# 0  40.635912 -74.026590            310.0             47.0       6800.0
# 1  40.720034 -73.989260            103.0              1.0       1800.0
# 2  40.751049 -73.982665            105.0              4.0       8400.0
# 3  40.857889 -73.886798            206.0             15.0      38900.0
# 4  40.759204 -73.986536            105.0              3.0      12500.0
#
#          BIN           BBL   NTA                                  Location
# 0  3145156.0  3.058620e+09  BK31  POINT (-74.026590008197 40.635912311744)
# 1  1088498.0  1.004150e+09  MN27  POINT (-73.989260331808 40.720034027074)
# 2  1016004.0  1.008400e+09  MN17  POINT (-73.982664852255 40.751049055485)
# 3  2011942.0  2.030670e+09  BX06  POINT (-73.886798180947 40.857888765766)
# 4  1024737.0  1.010180e+09  MN17  POINT (-73.986535905027 40.759204256088)
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Missing Values Analysis

# %%
# Display statistical summary
print("Statistical Summary:")
df.describe()
# Out:
# Statistical Summary:
#               CAMIS        ZIPCODE          SCORE       Latitude  \
# count  2.956160e+05  292456.000000  278615.000000  294004.000000
# mean   4.812222e+07   10705.692778      25.310899      40.296405
# std    3.717048e+06     617.039619      18.947431       4.173213
# min    3.007544e+07    6605.000000       0.000000       0.000000
# 25%    5.000641e+07   10023.000000      12.000000      40.687067
# 50%    5.009548e+07   11101.000000      21.000000      40.732968
# 75%    5.013174e+07   11232.000000      33.000000      40.761237
# max    5.018560e+07   69361.000000     214.000000      40.912822
#
#            Longitude  Community Board  Council District   Census Tract  \
# count  294004.000000    290885.000000     290915.000000  290915.000000
# mean      -73.155832       254.621201         20.515752   29855.031968
# std         7.575621       130.358361         15.649426   31247.916590
# min       -74.249101       101.000000          1.000000     100.000000
# 25%       -73.988586       106.000000          4.000000    8000.000000
# 50%       -73.955714       302.000000         20.000000   17300.000000
# 75%       -73.893638       401.000000         34.000000   42600.000000
# max         0.000000       595.000000         51.000000  162100.000000
#
#                 BIN           BBL
# count  2.896890e+05  2.940040e+05
# mean   2.583174e+06  2.476137e+09
# std    1.356153e+06  1.337713e+09
# min    1.000000e+06  1.000000e+00
# 25%    1.050541e+06  1.010910e+09
# 50%    3.021633e+06  3.008020e+09
# 75%    4.011433e+06  4.006270e+09
# max    5.799501e+06  5.270001e+09

# %% [markdown]
# ## Statistical Summary

# %%
print(f"Shape: {df.shape}")
# Out:
# Shape: (295616, 27)

# %%
# Display data types and info
print("\nData Types and Info:")
df.info()
# Out:
# Data Types and Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 295616 entries, 0 to 295615
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   CAMIS                  295616 non-null  int64
#  1   DBA                    295614 non-null  str
#  2   BORO                   295616 non-null  str
#  3   BUILDING               294638 non-null  str
#  4   STREET                 295601 non-null  str
#  5   ZIPCODE                292456 non-null  float64
#  6   PHONE                  295535 non-null  object
#  7   CUISINE DESCRIPTION    292082 non-null  str
#  8   INSPECTION DATE        295616 non-null  str
#  9   ACTION                 292162 non-null  str
#  10  VIOLATION CODE         289808 non-null  str
#  11  VIOLATION DESCRIPTION  289808 non-null  str
#  12  CRITICAL FLAG          295616 non-null  str
#  13  SCORE                  278615 non-null  float64
#  14  GRADE                  145791 non-null  str
#  15  GRADE DATE             136254 non-null  str
#  16  RECORD DATE            295616 non-null  str
#  17  INSPECTION TYPE        292162 non-null  str
#  18  Latitude               294004 non-null  float64
#  19  Longitude              294004 non-null  float64
#  20  Community Board        290885 non-null  float64
#  21  Council District       290915 non-null  float64
#  22  Census Tract           290915 non-null  float64
#  23  BIN                    289689 non-null  float64
#  24  BBL                    294004 non-null  float64
#  25  NTA                    290885 non-null  str
#  26  Location               290885 non-null  str
# dtypes: float64(9), int64(1), object(1), str(16)
# memory usage: 60.9+ MB

# %%
#See how many null values are in each column --zeek
print(df.isnull().sum())
# Out:
# CAMIS                         0
# DBA                           2
# BORO                          0
# BUILDING                    978
# STREET                       15
# ZIPCODE                    3160
# PHONE                        81
# CUISINE DESCRIPTION        3534
# INSPECTION DATE               0
# ACTION                     3454
# VIOLATION CODE             5808
# VIOLATION DESCRIPTION      5808
# CRITICAL FLAG                 0
# SCORE                     17001
# GRADE                    149825
# GRADE DATE               159362
# RECORD DATE                   0
# INSPECTION TYPE            3454
# Latitude                   1612
# Longitude                  1612
# Community Board            4731
# Council District           4701
# Census Tract               4701
# BIN                        5927
# BBL                        1612
# NTA                        4731
# Location                   4731
# dtype: int64

# %%
#get rid of nulls
def clean_restaurant_inspection_data(df):
    # Make a copy to avoid modifying original
    df_clean = df.copy()
    
    # Basic info cleaning
    df_clean['DBA'] = df_clean['DBA'].fillna("Unknown Business")
    df_clean['BUILDING'] = df_clean['BUILDING'].fillna("No Number")
    df_clean['STREET'] = df_clean['STREET'].fillna("Unknown Street")
    df_clean['PHONE'] = df_clean['PHONE'].fillna("No Phone Listed")
    
    # Zipcode by borough
    df_clean['ZIPCODE'] = df_clean.groupby('BORO')['ZIPCODE'].transform(lambda x: x.fillna(x.median()))
    
    # Inspection related
    df_clean['CUISINE DESCRIPTION'] = df_clean['CUISINE DESCRIPTION'].fillna("Unspecified")
    df_clean['ACTION'] = df_clean['ACTION'].fillna("No Action Recorded")
    df_clean['INSPECTION TYPE'] = df_clean['INSPECTION TYPE'].fillna("Unspecified")
    df_clean['VIOLATION CODE'] = df_clean['VIOLATION CODE'].fillna("No Violation")
    df_clean['VIOLATION DESCRIPTION'] = df_clean['VIOLATION DESCRIPTION'].fillna("No Violation Found")
    
    # Grades and scores
    df_clean['SCORE'] = df_clean['SCORE'].fillna(-1)
    df_clean['GRADE'] = df_clean['GRADE'].fillna("Not Graded")
    df_clean['GRADE DATE'] = df_clean['GRADE DATE'].fillna(df_clean['INSPECTION DATE'])
    
    # Location data
    for coord in ['Latitude', 'Longitude']:
        df_clean[coord] = df_clean.groupby('BORO')[coord].transform(lambda x: x.fillna(x.median()))
    
    # Administrative boundaries - FIX HERE
    admin_cols = ['Community Board', 'Council District', 'Census Tract', 'NTA']
    for col in admin_cols:
        df_clean[col] = df_clean.groupby('BORO')[col].transform(lambda x: 
            x.fillna(x.mode().iloc[0] if not x.mode().empty else -1))
    
    # Building numbers
    df_clean['BIN'] = df_clean['BIN'].fillna(0)
    df_clean['BBL'] = df_clean['BBL'].fillna(0)
    
    # Location string
    df_clean['Location'] = df_clean['Location'].fillna('Unknown Location')
    
    return df_clean

# %%
# Import Required Libraries
# !pip install matplotlib
# !pip install seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
# Out:
# Requirement already satisfied: matplotlib in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: seaborn in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (3.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Our new filtered year
df["INSPECTION DATE"] = pd.to_datetime(df["INSPECTION DATE"], errors="coerce")

# Filter from 2022 to 2025
df_filtered_2022_2025 = df[
    (df["INSPECTION DATE"].dt.year >= 2022) &
    (df["INSPECTION DATE"].dt.year <= 2025)
]

# Check shape
print("Filtered Shape (2022–2025):", df_filtered_2022_2025.shape)

# Preview
df_filtered_2022_2025.head()
# Out:
# Filtered Shape (2022–2025): (258107, 27)
#        CAMIS                                    DBA       BORO BUILDING  \
# 6   40387418                        TAL BAGELS DELI  Manhattan   975979
# 9   40741728                                 WALLSE  Manhattan   342344
# 11  41701450  CIBO EXPRESS FOOD COURT (CONCOURSE D)     Queens      NaN
# 18  50131935                                 Beacon     Queens      NaN
# 20  50121182              DELUCA ITALIAN RESTAURANT          0     7324
#
#                      STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 6              FIRST AVENUE      NaN  2127539080     Bagels/Pretzels
# 9            WEST 11 STREET      NaN  2123522300         Continental
# 11        LAGUARDIA AIRPORT  11369.0  9296230872          Sandwiches
# 18  Airport Terminal 4 CA11  11432.0  4706221735            American
# 20                 AMBOY RD  10307.0  3476725335             Italian
#
#    INSPECTION DATE  \
# 6       2025-05-27
# 9       2023-05-02
# 11      2024-10-30
# 18      2025-05-28
# 20      2024-01-22
#
#                                                          ACTION  \
# 6               Violations were cited in the following area(s).
# 9               Violations were cited in the following area(s).
# 11  No violations were recorded at the time of this inspection.
# 18              Violations were cited in the following area(s).
# 20              Violations were cited in the following area(s).
#
#    VIOLATION CODE  \
# 6             02B
# 9             02B
# 11            NaN
# 18            06E
# 20            04M
#
#                                                                                    VIOLATION DESCRIPTION  \
# 6                                                         Hot TCS food item not held at or above 140 °F.
# 9                                                         Hot TCS food item not held at or above 140 °F.
# 11                                                                                                   NaN
# 18  Sanitized equipment or utensil, including in-use food dispensing utensil, improperly used or stored.
# 20                                                     Live roaches in facility's food or non-food area.
#
#      CRITICAL FLAG  SCORE GRADE  GRADE DATE RECORD DATE  \
# 6         Critical   10.0   NaN         NaN  05/01/2026
# 9         Critical   18.0   NaN         NaN  05/01/2026
# 11  Not Applicable    0.0     A  10/30/2024  05/01/2026
# 18        Critical   11.0     A  05/28/2025  05/01/2026
# 20        Critical   26.0   NaN         NaN  05/01/2026
#
#                                   INSPECTION TYPE  Latitude  Longitude  \
# 6           Cycle Inspection / Initial Inspection       0.0        0.0
# 9           Cycle Inspection / Initial Inspection       0.0        0.0
# 11          Cycle Inspection / Initial Inspection       NaN        NaN
# 18  Pre-permit (Operational) / Initial Inspection       NaN        NaN
# 20          Cycle Inspection / Initial Inspection       NaN        NaN
#
#     Community Board  Council District  Census Tract  BIN  BBL  NTA Location
# 6               NaN               NaN           NaN  NaN  1.0  NaN      NaN
# 9               NaN               NaN           NaN  NaN  1.0  NaN      NaN
# 11              NaN               NaN           NaN  NaN  NaN  NaN      NaN
# 18              NaN               NaN           NaN  NaN  NaN  NaN      NaN
# 20              NaN               NaN           NaN  NaN  NaN  NaN      NaN

# %%
print("Original:", df.shape)
print("2022–2025:", df_filtered_2022_2025.shape)

print(
    df_filtered_2022_2025["INSPECTION DATE"].min(),
    "to",
    df_filtered_2022_2025["INSPECTION DATE"].max()
)
# Out:
# Original: (295616, 27)
# 2022–2025: (258107, 27)
# 2022-01-03 00:00:00 to 2025-12-31 00:00:00

# %% [markdown]
# ## Saved Output
#
# This notebook saves a cleaned version of the filtered dataset for use in later notebooks.

# %%
# Author: Jessica
# Creating shared_data folder if it doesn’t exist, then saving cleaned dataset

import os

os.makedirs("shared_data", exist_ok=True)

cleaned_path = "shared_data/cleaned_inspections.csv"
df_filtered_2022_2025.to_csv(cleaned_path, index=False)

print(f"Saved cleaned dataset to {cleaned_path}")
# Out:
# Saved cleaned dataset to shared_data/cleaned_inspections.csv
