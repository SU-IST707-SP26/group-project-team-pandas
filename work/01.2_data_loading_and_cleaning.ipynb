# %% [markdown]
# # 01 Data Loading and Cleaning
#
# This notebook loads the NYC restaurant inspection dataset, checks missingness and structure, and performs the initial cleaning and year filtering used throughout the project.

# %%
"""# Author: Jessica
# Loading packages used in this notebook

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt"""
# Out:
# '# Author: Jessica\n# Loading packages used in this notebook\n\nimport pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt'

# %%
# Author: Jessica
# Loading the raw inspection dataset so this notebook runs independently

"""df = pd.read_csv("https://data.cityofnewyork.us/api/views/43nn-pn8j/rows.csv?accessType=DOWNLOAD")
print(df.shape)
df.head()"""
# Out:
# 'df = pd.read_csv("https://data.cityofnewyork.us/api/views/43nn-pn8j/rows.csv?accessType=DOWNLOAD")\nprint(df.shape)\ndf.head()'

# %% [markdown]
# ## Uploading Data
# This notebook performs initial exploratory data analysis (EDA) on the restaurant inspection dataset to understand its structure, contents, and basic statistics.

# %%
# %pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 48.9 MB/s  0:00:006m0:00:01
# Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 60.3 MB/s  0:00:006m0:00:01
# Installing collected packages: numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# Successfully installed numpy-2.4.4 pandas-3.0.2
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# uploading data 
import pandas as pd

# NYC Open Data CSV download link
url = "https://data.cityofnewyork.us/api/views/43nn-pn8j/rows.csv?accessType=DOWNLOAD"

# Read directly from the web
df = pd.read_csv(url)

print("Shape:", df.shape)

# Preview
df.head()
# Out:
# Shape: (296011, 27)
# /tmp/ipykernel_13063/703061283.py:8: DtypeWarning: Columns (0: PHONE) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)
#       CAMIS                       DBA       BORO  BUILDING           STREET  \
# 0  50182749                  ONE BOWL          0       NaN              NaN
# 1  50179776  HALAL HIBACHI BITES INC.     Queens    180-06  HILLSIDE AVENUE
# 2  50107389    FULGURANCES LAUNDROMAT  Manhattan       132  FRANKLIN STREET
# 3  40837042        MALECON RESTAURANT      Bronx  55925594         BROADWAY
# 4  50183197      O'S NATURAL FOOD INC   Brooklyn       683    MYRTLE AVENUE
#
#    ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0      NaN  6467033578                 NaN      01/01/1900
# 1  11432.0  3478559220                 NaN      01/01/1900
# 2  10013.0  9293059235                 NaN      01/01/1900
# 3      NaN  7184325155      Latin American      12/12/2022
# 4  11205.0  7183882202                 NaN      01/01/1900
#
#                                             ACTION  ...  \
# 0                                              NaN  ...
# 1                                              NaN  ...
# 2                                              NaN  ...
# 3  Violations were cited in the following area(s).  ...
# 4                                              NaN  ...
#
#                     INSPECTION TYPE   Latitude  Longitude  Community Board  \
# 0                               NaN        NaN        NaN              NaN
# 1                               NaN  40.712983 -73.782380            412.0
# 2                               NaN  40.719153 -74.007201            101.0
# 3  Cycle Inspection / Re-inspection   0.000000   0.000000              NaN
# 4                               NaN  40.694604 -73.955918            303.0
#
#   Council District Census Tract        BIN           BBL   NTA  \
# 0              NaN          NaN        NaN           NaN   NaN
# 1             23.0      46800.0  4212376.0  4.099160e+09  QN61
# 2              1.0       3300.0  1000000.0  1.001898e+09  MN24
# 3              NaN          NaN        NaN  2.000000e+00   NaN
# 4             33.0     123700.0  3048424.0  3.017340e+09  BK75
#
#                                    Location
# 0                                       NaN
# 1  POINT (-73.782379562217 40.712982592081)
# 2  POINT (-74.007200568792 40.719153233456)
# 3                                       NaN
# 4  POINT (-73.955918225228 40.694603994123)
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Missing Values Analysis

# %%
# Display statistical summary
print("Statistical Summary:")
df.describe()
# Out:
# Statistical Summary:
#               CAMIS        ZIPCODE          SCORE       Latitude  \
# count  2.960110e+05  292838.000000  279018.000000  294391.000000
# mean   4.812583e+07   10705.928520      25.332505      40.295177
# std    3.714751e+06     616.981014      18.976040       4.179086
# min    3.007544e+07    6605.000000       0.000000       0.000000
# 25%    5.000670e+07   10023.000000      12.000000      40.687067
# 50%    5.009572e+07   11101.000000      21.000000      40.732962
# 75%    5.013189e+07   11232.000000      33.000000      40.761232
# max    5.018564e+07   69361.000000     214.000000      40.912822
#
#            Longitude  Community Board  Council District   Census Tract  \
# count  294391.000000    291259.000000     291289.000000  291289.000000
# mean      -73.153577       254.643757         20.518121   29851.697884
# std         7.586282       130.333429         15.647526   31245.169022
# min       -74.249101       101.000000          1.000000     100.000000
# 25%       -73.988583       106.000000          4.000000    8000.000000
# 50%       -73.955709       302.000000         20.000000   17300.000000
# 75%       -73.893529       401.000000         34.000000   42600.000000
# max         0.000000       595.000000         51.000000  162100.000000
#
#                 BIN           BBL
# count  2.900630e+05  2.943910e+05
# mean   2.583428e+06  2.476305e+09
# std    1.355905e+06  1.337516e+09
# min    1.000000e+06  1.000000e+00
# 25%    1.050593e+06  1.010940e+09
# 50%    3.021680e+06  3.008020e+09
# 75%    4.011433e+06  4.006270e+09
# max    5.799501e+06  5.270001e+09

# %% [markdown]
# ## Statistical Summary

# %%
print(f"Shape: {df.shape}")
# Out:
# Shape: (296011, 27)

# %%
# Display data types and info
print("\nData Types and Info:")
df.info()
# Out:
# Data Types and Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 296011 entries, 0 to 296010
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   CAMIS                  296011 non-null  int64
#  1   DBA                    296009 non-null  str
#  2   BORO                   296011 non-null  str
#  3   BUILDING               295033 non-null  str
#  4   STREET                 295996 non-null  str
#  5   ZIPCODE                292838 non-null  float64
#  6   PHONE                  295930 non-null  object
#  7   CUISINE DESCRIPTION    292502 non-null  str
#  8   INSPECTION DATE        296011 non-null  str
#  9   ACTION                 292582 non-null  str
#  10  VIOLATION CODE         290220 non-null  str
#  11  VIOLATION DESCRIPTION  290220 non-null  str
#  12  CRITICAL FLAG          296011 non-null  str
#  13  SCORE                  279018 non-null  float64
#  14  GRADE                  146041 non-null  str
#  15  GRADE DATE             136454 non-null  str
#  16  RECORD DATE            296011 non-null  str
#  17  INSPECTION TYPE        292582 non-null  str
#  18  Latitude               294391 non-null  float64
#  19  Longitude              294391 non-null  float64
#  20  Community Board        291259 non-null  float64
#  21  Council District       291289 non-null  float64
#  22  Census Tract           291289 non-null  float64
#  23  BIN                    290063 non-null  float64
#  24  BBL                    294391 non-null  float64
#  25  NTA                    291259 non-null  str
#  26  Location               291259 non-null  str
# dtypes: float64(9), int64(1), object(1), str(16)
# memory usage: 61.0+ MB

# %%
#See how many null values are in each column --zeek
print(df.isnull().sum())
# Out:
# CAMIS                         0
# DBA                           2
# BORO                          0
# BUILDING                    978
# STREET                       15
# ZIPCODE                    3173
# PHONE                        81
# CUISINE DESCRIPTION        3509
# INSPECTION DATE               0
# ACTION                     3429
# VIOLATION CODE             5791
# VIOLATION DESCRIPTION      5791
# CRITICAL FLAG                 0
# SCORE                     16993
# GRADE                    149970
# GRADE DATE               159557
# RECORD DATE                   0
# INSPECTION TYPE            3429
# Latitude                   1620
# Longitude                  1620
# Community Board            4752
# Council District           4722
# Census Tract               4722
# BIN                        5948
# BBL                        1620
# NTA                        4752
# Location                   4752
# dtype: int64

# %%
#get rid of nulls
def clean_restaurant_inspection_data(df):
    # Make a copy to avoid modifying original
    df_clean = df.copy()
    
    # Basic info cleaning
    df_clean['DBA'] = df_clean['DBA'].fillna("Unknown Business")
    df_clean['BUILDING'] = df_clean['BUILDING'].fillna("No Number")
    df_clean['STREET'] = df_clean['STREET'].fillna("Unknown Street")
    df_clean['PHONE'] = df_clean['PHONE'].fillna("No Phone Listed")
    
    # Zipcode by borough
    df_clean['ZIPCODE'] = df_clean.groupby('BORO')['ZIPCODE'].transform(lambda x: x.fillna(x.median()))
    
    # Inspection related
    df_clean['CUISINE DESCRIPTION'] = df_clean['CUISINE DESCRIPTION'].fillna("Unspecified")
    df_clean['ACTION'] = df_clean['ACTION'].fillna("No Action Recorded")
    df_clean['INSPECTION TYPE'] = df_clean['INSPECTION TYPE'].fillna("Unspecified")
    df_clean['VIOLATION CODE'] = df_clean['VIOLATION CODE'].fillna("No Violation")
    df_clean['VIOLATION DESCRIPTION'] = df_clean['VIOLATION DESCRIPTION'].fillna("No Violation Found")
    
    # Grades and scores
    df_clean['SCORE'] = df_clean['SCORE'].fillna(-1)
    df_clean['GRADE'] = df_clean['GRADE'].fillna("Not Graded")
    df_clean['GRADE DATE'] = df_clean['GRADE DATE'].fillna(df_clean['INSPECTION DATE'])
    
    # Location data
    for coord in ['Latitude', 'Longitude']:
        df_clean[coord] = df_clean.groupby('BORO')[coord].transform(lambda x: x.fillna(x.median()))
    
    # Administrative boundaries - FIX HERE
    admin_cols = ['Community Board', 'Council District', 'Census Tract', 'NTA']
    for col in admin_cols:
        df_clean[col] = df_clean.groupby('BORO')[col].transform(lambda x: 
            x.fillna(x.mode().iloc[0] if not x.mode().empty else -1))
    
    # Building numbers
    df_clean['BIN'] = df_clean['BIN'].fillna(0)
    df_clean['BBL'] = df_clean['BBL'].fillna(0)
    
    # Location string
    df_clean['Location'] = df_clean['Location'].fillna('Unknown Location')
    
    return df_clean

# %%
# Import Required Libraries
# !pip install matplotlib
# !pip install seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.23 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 53.2 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 50.9 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 40.9 MB/s  0:00:00
# Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 53.1 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.9 pillow-12.2.0 pyparsing-3.3.2
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (3.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# Our new filtered year
df["INSPECTION DATE"] = pd.to_datetime(df["INSPECTION DATE"], errors="coerce")

# Filter from 2022 to 2025
df_filtered_2022_2025 = df[
    (df["INSPECTION DATE"].dt.year >= 2022) &
    (df["INSPECTION DATE"].dt.year <= 2025)
]

# Check shape
print("Filtered Shape (2022–2025):", df_filtered_2022_2025.shape)

# Preview
df_filtered_2022_2025.head()
# Out:
# Filtered Shape (2022–2025): (257539, 27)
#        CAMIS                 DBA      BORO  BUILDING               STREET  \
# 3   40837042  MALECON RESTAURANT     Bronx  55925594             BROADWAY
# 8   40380164         CUCHIFRITOS     Bronx       158         E. 188 TH ST
# 10  41202725              DUNKIN    Queens     75-20            37 AVENUE
# 14  50108462       THE MAC SHACK  Brooklyn       320  MALCOLM X BOULEVARD
# 17  41241298             ALCHEMY  Brooklyn        56             5 AVENUE
#
#     ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 3       NaN  7184325155      Latin American      2022-12-12
# 8       NaN  7183674500             Spanish      2022-01-24
# 10  11372.0  7183975660            American      2024-08-05
# 14  11233.0  7182109603            American      2024-06-15
# 17  11217.0  7186364385            American      2025-04-17
#
#                                                          ACTION  \
# 3               Violations were cited in the following area(s).
# 8               Violations were cited in the following area(s).
# 10  No violations were recorded at the time of this inspection.
# 14  No violations were recorded at the time of this inspection.
# 17              Violations were cited in the following area(s).
#
#    VIOLATION CODE  \
# 3             04L
# 8             04L
# 10            NaN
# 14            NaN
# 17            02B
#
#                                                               VIOLATION DESCRIPTION  \
# 3          Evidence of mice or live mice in establishment's food or non-food areas.
# 8   Evidence of mice or live mice present in facility's food and/or non-food areas.
# 10                                                                              NaN
# 14                                                                              NaN
# 17                                   Hot TCS food item not held at or above 140 °F.
#
#      CRITICAL FLAG  SCORE GRADE  GRADE DATE RECORD DATE  \
# 3         Critical   23.0     B  12/12/2022  05/04/2026
# 8         Critical   16.0     B  01/24/2022  05/04/2026
# 10  Not Applicable    0.0     A  08/05/2024  05/04/2026
# 14  Not Applicable    0.0   NaN         NaN  05/04/2026
# 17        Critical   29.0     C  04/17/2025  05/04/2026
#
#                                  INSPECTION TYPE   Latitude  Longitude  \
# 3               Cycle Inspection / Re-inspection   0.000000   0.000000
# 8               Cycle Inspection / Re-inspection   0.000000   0.000000
# 10              Cycle Inspection / Re-inspection  40.749077 -73.890546
# 14  Inter-Agency Task Force / Initial Inspection  40.681852 -73.928857
# 17              Cycle Inspection / Re-inspection  40.681290 -73.977163
#
#     Community Board  Council District  Census Tract        BIN           BBL  \
# 3               NaN               NaN           NaN        NaN  2.000000e+00
# 8               NaN               NaN           NaN        NaN  2.000000e+00
# 10            403.0              25.0       28700.0  4029851.0  4.012860e+09
# 14            303.0              36.0       29700.0  3047511.0  3.016810e+09
# 17            306.0              39.0       12901.0  3018543.0  3.009320e+09
#
#      NTA                                  Location
# 3    NaN                                       NaN
# 8    NaN                                       NaN
# 10  QN28  POINT (-73.890546005406 40.749076826787)
# 14  BK61  POINT (-73.928856784586 40.681851895564)
# 17  BK37    POINT (-73.9771631224 40.681289806446)

# %%
print("Original:", df.shape)
print("2022–2025:", df_filtered_2022_2025.shape)

print(
    df_filtered_2022_2025["INSPECTION DATE"].min(),
    "to",
    df_filtered_2022_2025["INSPECTION DATE"].max()
)
# Out:
# Original: (296011, 27)
# 2022–2025: (257539, 27)
# 2022-01-03 00:00:00 to 2025-12-31 00:00:00

# %% [markdown]
# ## Saved Output
#
# This notebook saves a cleaned version of the filtered dataset for use in later notebooks.

# %%
# Author: Jessica
# Creating shared_data folder if it doesn’t exist, then saving cleaned dataset

import os

os.makedirs("shared_data", exist_ok=True)

cleaned_path = "shared_data/cleaned_inspections.csv"
df_filtered_2022_2025.to_csv(cleaned_path, index=False)

print(f"Saved cleaned dataset to {cleaned_path}")
# Out:
# Saved cleaned dataset to shared_data/cleaned_inspections.csv
